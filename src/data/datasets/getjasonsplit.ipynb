# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import json
import scipy
import numpy as np
import random

# %% [markdown]
# Output CUB split jason files

# %%
# Define paths
dataset_root = '/storage/data/changyu/CUB_200_2011'
images_path = os.path.join(dataset_root, 'images.txt')
splits_path = os.path.join(dataset_root, 'train_test_split.txt')
image_class_labels_path = os.path.join(dataset_root, 'image_class_labels.txt')

# %%
 # Load dataset information
splits = pd.read_csv(splits_path, sep=' ', names=['img_id', 'is_train'])
labels = pd.read_csv(image_class_labels_path, sep=' ', names=['img_id', 'label'])
images = pd.read_csv(images_path, sep=' ', names=['img_id', 'image_name'])

# Merge splits and labels
data_info = pd.merge(splits, labels, on='img_id')
data_info = pd.merge(data_info, images, on='img_id')

# %%
# Train-test split provided by the dataset
train_data = data_info[data_info['is_train'] == 1]
test_data = data_info[data_info['is_train'] == 0]

# %%
# Split the original training data to create a validation set
train_data, val_data = train_test_split(train_data, test_size=0.10, random_state=42, stratify=train_data['label'])

# %%
#save data to json
train_json, val_json, test_json = {},{},{}
for i in range(train_data.shape[0]):
    img_path = train_data.iloc[i,3]
    train_json[img_path] = int(train_data.iloc[i,2])

for i in range(val_data.shape[0]):
    img_path = val_data.iloc[i,3]
    val_json[img_path] = int(val_data.iloc[i,2])

for i in range(test_data.shape[0]):
    img_path = test_data.iloc[i,3]
    test_json[img_path] = int(test_data.iloc[i,2])

# %%
# Save json files
json_file_path = os.path.join(dataset_root, 'train.json')
with open(json_file_path, 'w') as f:
    json.dump(train_json, f, indent=4)

json_file_path = os.path.join(dataset_root, 'val.json')
with open(json_file_path, 'w') as f:
    json.dump(val_json, f, indent=4)

json_file_path = os.path.join(dataset_root, 'test.json')
with open(json_file_path, 'w') as f:
    json.dump(test_json, f, indent=4)

# %%
train_data["label"].value_counts()
# Out:
# label
# 103    27
# 191    27
# 55     27
# 45     27
# 10     27
#        ..
# 107    26
# 196    26
# 190    26
# 141    26
# 126    26
# Name: count, Length: 200, dtype: int64

# %%
val_data["label"].value_counts()
# Out:
# label
# 32     3
# 143    3
# 177    3
# 130    3
# 86     3
#       ..
# 146    3
# 43     3
# 162    3
# 124    3
# 88     3
# Name: count, Length: 200, dtype: int64

# %%
test_data["label"].value_counts()
# Out:
# label
# 1      30
# 143    30
# 120    30
# 121    30
# 122    30
#        ..
# 105    19
# 8      18
# 18     15
# 5      14
# 6      11
# Name: count, Length: 200, dtype: int64

# %% [markdown]
# Output Flower split jason files

# %%
dataset_root_flower = '/storage/data/changyu/OxfordFlowers'
split = scipy.io.loadmat('/storage/data/changyu/OxfordFlowers/setid.mat')          #train and val is 50% and 50%, we will resplit it to 90% and 10%
labels = scipy.io.loadmat('/storage/data/changyu/OxfordFlowers/imagelabels.mat')
labels = labels['labels'].reshape(-1)
train_idx = split['trnid'].reshape(-1) -1
val_idx = split['valid'].reshape(-1) -1
test_idx = split['tstid'].reshape(-1) -1

# %%
#get all the image relative paths under /storage/data/changyu/Flower
image_paths = []
for root, dirs, files in os.walk(dataset_root_flower):   
    for file in files:
        if file.endswith('.jpg'):
            image_paths.append(os.path.relpath(os.path.join(root, file), dataset_root_flower))
image_paths = sorted(image_paths)

# %%
#merge train and val, then split it to 90% and 10%
train_val_idx = np.concatenate((train_idx, val_idx))
train_idx_new, val_idx_new = train_test_split(train_val_idx, test_size=0.10, random_state=42, stratify=labels[train_val_idx])

# %%
#form the split json files with the format of {image_path: label}
train_json, val_json, test_json = {},{},{}
for i in train_idx_new:
    img_path = image_paths[i]
    train_json[img_path] = int(labels[i])

for i in val_idx_new:
    img_path = image_paths[i]
    val_json[img_path] = int(labels[i])

for i in test_idx:
    img_path = image_paths[i]
    test_json[img_path] = int(labels[i])    

# Save json files
with open(os.path.join(dataset_root_flower, 'train.json'), 'w') as f:
    json.dump(train_json, f, indent=4)

with open(os.path.join(dataset_root_flower, 'val.json'), 'w') as f:
    json.dump(val_json, f, indent=4)

with open(os.path.join(dataset_root_flower, 'test.json'), 'w') as f:
    json.dump(test_json, f, indent=4)

# %% [markdown]
# Get Aircraft split jason files

# %%
# read the variants.txt file
variants = pd.read_csv('/storage/data/changyu/fgvc-aircraft-2013b/data/variants.txt', header=None, names=['Variant'])

# Reset the index so it becomes a column in the DataFrame
variants.reset_index(inplace=True)
variants.rename(columns={'index': 'Variant_Index'}, inplace=True)
variants['Variant_Index'] = variants['Variant_Index'] + 1
print(variants.head())
# Out:
#    Variant_Index  Variant
# 0              1  707-320
# 1              2  727-200
# 2              3  737-200
# 3              4  737-300
# 4              5  737-400

# %%
# Load the image to variant mappings
images_variant_test = pd.read_csv('/storage/data/changyu/fgvc-aircraft-2013b/data/images_variant_test.txt', header=None, names=['Combined'])
images_variant_trainval = pd.read_csv('/storage/data/changyu/fgvc-aircraft-2013b/data/images_variant_trainval.txt', header=None, names=['Combined'])

# Split the 'Combined' column into two columns at the first space
images_variant_test[['Filename', 'Variant']] = images_variant_test['Combined'].str.split(n=1, expand=True)
images_variant_trainval[['Filename', 'Variant']] = images_variant_trainval['Combined'].str.split(n=1, expand=True)

merged_test = pd.merge(images_variant_test, variants, on='Variant', how='left')
merged_trainval = pd.merge(images_variant_trainval, variants, on='Variant', how='left')

#use Filename to get the relative path
merged_test['re_path'] = 'data/images/' + merged_test['Filename'] + '.jpg'
merged_trainval['re_path'] = 'data/images/' + merged_trainval['Filename'] + '.jpg'

print(merged_test.head())
print(merged_trainval.head())
# Out:
#           Combined Filename  Variant  Variant_Index                  re_path
# 0  1514522 707-320  1514522  707-320              1  data/images/1514522.jpg
# 1  0747566 707-320  0747566  707-320              1  data/images/0747566.jpg
# 2  1008575 707-320  1008575  707-320              1  data/images/1008575.jpg
# 3  0717480 707-320  0717480  707-320              1  data/images/0717480.jpg
# 4  0991569 707-320  0991569  707-320              1  data/images/0991569.jpg
#           Combined Filename  Variant  Variant_Index                  re_path
# 0  1025794 707-320  1025794  707-320              1  data/images/1025794.jpg
# 1  1340192 707-320  1340192  707-320              1  data/images/1340192.jpg
# 2  0056978 707-320  0056978  707-320              1  data/images/0056978.jpg
# 3  0698580 707-320  0698580  707-320              1  data/images/0698580.jpg
# 4  0450014 707-320  0450014  707-320              1  data/images/0450014.jpg

# %%
#Split the trainval to train and val with 90% and 10%
trainval_idx = merged_trainval.index
train_idx_new, val_idx_new = train_test_split(trainval_idx, test_size=0.10, random_state=42, stratify=merged_trainval['Variant_Index'])

# %%
# save the json files
train_json, val_json, test_json = {},{},{}
for i in train_idx_new:
    img_path = merged_trainval.iloc[i,4]
    train_json[img_path] = int(merged_trainval.iloc[i,3])

for i in val_idx_new:
    img_path = merged_trainval.iloc[i,4]
    val_json[img_path] = int(merged_trainval.iloc[i,3])

for i in range(merged_test.shape[0]):
    img_path = merged_test.iloc[i,4]
    test_json[img_path] = int(merged_test.iloc[i,3])

# Save json files
with open('/storage/data/changyu/fgvc-aircraft-2013b/train.json', 'w') as f:
    json.dump(train_json, f, indent=4)

with open('/storage/data/changyu/fgvc-aircraft-2013b/val.json', 'w') as f:
    json.dump(val_json, f, indent=4)

with open('/storage/data/changyu/fgvc-aircraft-2013b/test.json', 'w') as f:
    json.dump(test_json, f, indent=4)

# %%
# the ratio of the number of images in each class to the total number of images
print(merged_trainval.iloc[train_idx_new]['Variant_Index'].value_counts())
print(merged_trainval.iloc[val_idx_new]['Variant_Index'].value_counts())
print(merged_test['Variant_Index'].value_counts())

# %% [markdown]
# Get stanford cars split jason files
#
#
# download dataset according to https://github.com/pytorch/vision/issues/7545

# %%
test_data = scipy.io.loadmat('/storage/data/changyu/StanfordCars/cars_test_annos_withlabels (1).mat')
train_data = scipy.io.loadmat('/storage/data/changyu/StanfordCars/devkit/cars_train_annos.mat')

# %%
test_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'annotations': array([[(array([[30]], dtype=uint8), array([[52]], dtype=uint8), array([[246]], dtype=uint8), array([[147]], dtype=uint8), array([[181]], dtype=uint8), array(['00001.jpg'], dtype='<U9')),
#          (array([[100]], dtype=uint8), array([[19]], dtype=uint8), array([[576]], dtype=uint16), array([[203]], dtype=uint8), array([[103]], dtype=uint8), array(['00002.jpg'], dtype='<U9')),
#          (array([[51]], dtype=uint8), array([[105]], dtype=uint8), array([[968]], dtype=uint16), array([[659]], dtype=uint16), array([[145]], dtype=uint8), array(['00003.jpg'], dtype='<U9')),
#          ...,
#          (array([[33]], dtype=uint8), array([[27]], dtype=uint8), array([[602]], dtype=uint16), array([[252]], dtype=uint8), array([[17]], dtype=uint8), array(['08039.jpg'], dtype='<U9')),
#          (array([[33]], dtype=uint8), array([[142]], dtype=uint8), array([[521]], dtype=uint16), array([[376]], dtype=uint16), array([[38]], dtype=uint8), array(['08040.jpg'], dtype='<U9')),
#          (array([[77]], dtype=uint8), array([[73]], dtype=uint8), array([[506]], dtype=uint16), array([[380]], dtype=uint16), array([[32]], dtype=uint8), array(['08041.jpg'], dtype='<U9'))]],
#        dtype=[('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('fname', 'O')])}

# %%
train_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'annotations': array([[(array([[39]], dtype=uint8), array([[116]], dtype=uint8), array([[569]], dtype=uint16), array([[375]], dtype=uint16), array([[14]], dtype=uint8), array(['00001.jpg'], dtype='<U9')),
#          (array([[36]], dtype=uint8), array([[116]], dtype=uint8), array([[868]], dtype=uint16), array([[587]], dtype=uint16), array([[3]], dtype=uint8), array(['00002.jpg'], dtype='<U9')),
#          (array([[85]], dtype=uint8), array([[109]], dtype=uint8), array([[601]], dtype=uint16), array([[381]], dtype=uint16), array([[91]], dtype=uint8), array(['00003.jpg'], dtype='<U9')),
#          ...,
#          (array([[26]], dtype=uint8), array([[246]], dtype=uint8), array([[660]], dtype=uint16), array([[449]], dtype=uint16), array([[163]], dtype=uint8), array(['08142.jpg'], dtype='<U9')),
#          (array([[78]], dtype=uint8), array([[526]], dtype=uint16), array([[1489]], dtype=uint16), array([[908]], dtype=uint16), array([[112]], dtype=uint8), array(['08143.jpg'], dtype='<U9')),
#          (array([[20]], dtype=uint8), array([[240]], dtype=uint8), array([[862]], dtype=uint16), array([[677]], dtype=uint16), array([[17]], dtype=uint8), array(['08144.jpg'], dtype='<U9'))]],
#        dtype=[('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('fname', 'O')])}

# %% [markdown]
# Get stanford dogs split jason files

# %%
test_data = scipy.io.loadmat("/storage/data/changyu/StanfordDogs/test_list.mat")
train_data = scipy.io.loadmat("/storage/data/changyu/StanfordDogs/train_list.mat")
file_list = scipy.io.loadmat("/storage/data/changyu/StanfordDogs/file_list.mat")

# %%
#extract test data to a jason with image_path and label
# test_json = {}
# for i in range(len(test_data['file_list'])):
#     img_path = test_data['file_list'][i][0][0]
#     label = test_data['labels'][i][0]
#     test_json[img_path] = int(label)
# Out:
# 1

# %%
#extract train data to a dataframe with image_path and label columns
train_df = pd.DataFrame(columns=['image_path', 'label'])
for i in range(len(train_data['file_list'])):
    img_path = train_data['file_list'][i][0][0]
    label = int(train_data['labels'][i][0])
    train_df.loc[i, 'image_path'] = img_path
    train_df.loc[i, 'label'] = label

test_df = pd.DataFrame(columns=['image_path', 'label'])
for i in range(len(test_data['file_list'])):
    img_path = test_data['file_list'][i][0][0]
    label = int(test_data['labels'][i][0])
    test_df.loc[i, 'image_path'] = img_path
    test_df.loc[i, 'label'] = label

# %%
#split the train data to train and val with 90% and 10%
train_df_new, val_df_new = train_test_split(train_df, test_size=0.10, random_state=42, stratify=train_df['label'])

#save the json files
train_json, val_json, test_json = {},{},{}
for i in range(train_df_new.shape[0]):
    img_path = train_df_new.iloc[i,0]
    label = train_df_new.iloc[i,1]
    train_json[img_path] = label

for i in range(val_df_new.shape[0]):
    img_path = val_df_new.iloc[i,0]
    label = val_df_new.iloc[i,1]
    val_json[img_path] = label

for i in range(test_df.shape[0]):
    img_path = test_df.iloc[i,0]
    label = test_df.iloc[i,1]
    test_json[img_path] = label

# %%
# Save json files
with open('/storage/data/changyu/StanfordDogs/train.json', 'w') as f:
    json.dump(train_json, f, indent=4)

with open('/storage/data/changyu/StanfordDogs/val.json', 'w') as f:
    json.dump(val_json, f, indent=4)

with open('/storage/data/changyu/StanfordDogs/test.json', 'w') as f:
    json.dump(test_json, f, indent=4)

# %%
print(test_df['label'].value_counts())
# Out:
# label
# 3      152
# 10     139
# 27     132
# 108    119
# 89     118
#       ...
# 71      50
# 101     50
# 83      50
# 4       49
# 18      48
# Name: count, Length: 120, dtype: int64

# %%
# count the number of images in each class to the total number of images
print(train_df_new['label'].value_counts())
print(val_df_new['label'].value_counts())
# Out:
# label
# 56     90
# 17     90
# 68     90
# 58     90
# 101    90
#        ..
# 5      90
# 16     90
# 52     90
# 38     90
# 80     90
# Name: count, Length: 120, dtype: int64
# label
# 82     10
# 87     10
# 68     10
# 116    10
# 20     10
#        ..
# 32     10
# 1      10
# 15     10
# 45     10
# 56     10
# Name: count, Length: 120, dtype: int64

# %% [markdown]
# Get nabirds split jason files

# %%
#read files to dataframe
image_class_labels = pd.read_csv('/storage/data/changyu/nabirds/image_class_labels.txt', sep=' ', names=['img_id', 'label'])
images = pd.read_csv('/storage/data/changyu/nabirds/images.txt', sep=' ', names=['img_id', 'image_re_path'])
splits = pd.read_csv('/storage/data/changyu/nabirds/train_test_split.txt', sep=' ', names=['img_id', 'is_train'])

#merge the dataframes
data_info = pd.merge(image_class_labels, images, on='img_id')
data_info = pd.merge(data_info, splits, on='img_id') 

#split train and test data
train_data = data_info[data_info['is_train'] == 1]
test_data = data_info[data_info['is_train'] == 0]

#split the train data to train and val with 90% and 10%
train_data_new, val_data_new = train_test_split(train_data, test_size=0.10, random_state=42, stratify=train_data['label'])

# %%
#!!!!!!!!Beacause the this split makes class 627 and 975 without any sample in the val set, 
#!!!!!!!!we add one sample from train set to val set.
#because the logic of json_dataset class, we make this modification
#add one sample from class 627 and 975 to val set
val_data_new = pd.concat([val_data_new, train_data_new[train_data_new['label']==627].iloc[[0]]], ignore_index=True)
val_data_new = pd.concat([val_data_new, train_data_new[train_data_new['label']==975].iloc[[0]]], ignore_index=True)
train_data_new = train_data_new.drop(train_data_new[train_data_new['label']==627].index[0])
train_data_new = train_data_new.drop(train_data_new[train_data_new['label']==975].index[0])

# %%
#save the json files
train_json, val_json, test_json = {},{},{}
for i in range(train_data_new.shape[0]):
    img_path = train_data_new.iloc[i,2]
    label = train_data_new.iloc[i,1]
    train_json[img_path] = int(label)

for i in range(val_data_new.shape[0]):
    img_path = val_data_new.iloc[i,2]
    label = val_data_new.iloc[i,1]
    val_json[img_path] = int(label)

for i in range(test_data.shape[0]):
    img_path = test_data.iloc[i,2]
    label = test_data.iloc[i,1]
    test_json[img_path] = int(label)

# Save json files
with open('/storage/data/changyu/nabirds/train.json', 'w') as f:
    json.dump(train_json, f, indent=4)

with open('/storage/data/changyu/nabirds/val.json', 'w') as f:
    json.dump(val_json, f, indent=4)

with open('/storage/data/changyu/nabirds/test.json', 'w') as f:
    json.dump(test_json, f, indent=4)

# %%
#count the number of images in each class to the total number of images
#print(train_data_new['label'].value_counts())
#print(val_data_new['label'].value_counts())
#print(test_data['label'].value_counts())

#save counts reults into dataframes with label as one column and counts as another column
train_counts = train_data_new['label'].value_counts().reset_index()
train_counts.columns = ['label', 'counts']
val_counts = val_data_new['label'].value_counts().reset_index()
val_counts.columns = ['label', 'counts']
test_counts = test_data['label'].value_counts().reset_index()
test_counts.columns = ['label', 'counts']


#merge the counts dataframes
merged_df = pd.merge(train_counts, val_counts, on='label', how='outer')
merged_df = pd.merge(merged_df, test_counts, on='label', how='outer')

# %%
#save the merged dataframe to a csv file
merged_df.to_csv('/storage/data/changyu/nabirds/label_counts.csv', index=False)

# %%
train_counts
# Out:
#      label  counts
# 0      979      54
# 1      935      54
# 2      400      54
# 3      320      54
# 4      778      54
# ..     ...     ...
# 550    807       7
# 551    633       6
# 552    815       5
# 553    627       4
# 554    975       3
#
# [555 rows x 2 columns]

# %%
val_counts
# Out:
#      label  counts
# 0      856       6
# 1      823       6
# 2      924       6
# 3      352       6
# 4      935       6
# ..     ...     ...
# 550    618       1
# 551    369       1
# 552    664       1
# 553    759       1
# 554    975       1
#
# [555 rows x 2 columns]

# %%
test_counts
# Out:
#      label  counts
# 0      657      60
# 1      922      60
# 2      856      60
# 3      655      60
# 4      823      60
# ..     ...     ...
# 550    755      12
# 551    599      12
# 552    464      12
# 553    664      11
# 554    975       9
#
# [555 rows x 2 columns]

# %% [markdown]
# Imagenet

# %%
import os
import tarfile
import argparse

def extract_tar(tar_path, extract_dir):
    """Extracts a tar file to the specified directory."""
    if not tarfile.is_tarfile(tar_path):
        raise ValueError(f"{tar_path} is not a valid tar file.")
    with tarfile.open(tar_path, "r") as tar:
        tar.extractall(path=extract_dir)
    print(f"Extracted {tar_path} to {extract_dir}")

def extract_imagenet_train(main_tar, output_dir, remove_subtars=True):
    # Ensure the output directory exists.
    os.makedirs(output_dir, exist_ok=True)
    
    # Step 1: Extract the main tar file.
    if os.path.exists(main_tar):
        print("Extracting main tar file...")
        extract_tar(main_tar, output_dir)

    # Step 2: For each class-specific tar file in the output directory, extract it.
    print("Extracting class-specific tar files...")
    for filename in os.listdir(output_dir):
        if filename.endswith(".tar"):
            tar_path = os.path.join(output_dir, filename)
            # Create a folder with the same name as the tar file (minus the .tar extension)
            class_dir = os.path.join(output_dir, filename[:-4])
            os.makedirs(class_dir, exist_ok=True)
            extract_tar(tar_path, class_dir)
            if remove_subtars:
                os.remove(tar_path)
                print(f"Removed {tar_path}")

# %%
#unzip the imagenet train data
extract_imagenet_train('/storage/data/changyu/imagenet/ILSVRC2012_img_train.tar', '/storage/data/changyu/imagenet/train')

# %%
# Set the paths to your validation images and the ground-truth label file.
val_dir = '/scratch/data/imagenet/val'
label_file = '/scratch/data/imagenet/ILSVRC2012_devkit_t12/data/ILSVRC2012_validation_ground_truth.txt'

# Read the ground truth labels; each line corresponds to an image.
with open(label_file, 'r') as f:
    labels = [line.strip() for line in f.readlines()]

val_images = sorted(os.listdir(val_dir))

# %%
# Build the mapping dictionary "path": label.
mapping = {}
for i, img_file in enumerate(val_images):
    # Full path to the image file
    img_path = os.path.join("val", img_file)
    
    # It's good to check that we have a label for each image.
    if i < len(labels):
        mapping[img_path] = int(labels[i])
    else:
        print(f"Warning: No label found for {img_file}")

# Write the mapping to a JSON file.
output_file = '/scratch/data/imagenet/val.json'
with open(output_file, 'w') as json_file:
    json.dump(mapping, json_file, indent=4)

print(f"JSON mapping file created successfully and saved as '{output_file}'.")
# Out:
# JSON mapping file created successfully and saved as '/scratch/data/imagenet/val.json'.

# %%
#Load the meta.mat file.
meta = scipy.io.loadmat("/scratch/data/imagenet/ILSVRC2012_devkit_t12/data/meta.mat")
synsets = meta['synsets']

# %%
#Build a mapping from wnid to a 0-indexed label (0 to 999)
wnid_to_label = {}
for idx, syn in enumerate(synsets):
    # Assuming the structure is like: [ 'ILSVRC2012_ID', 'WNID', 'words', ... ]
    # and that WNID is at index 1:
    wnid = syn[0][1][0]  # adjust index if needed based on meta.mat structure
    wnid_to_label[wnid] = syn[0][0][0][0]

# %%
wnid_to_label["n02092339"]
# Out:
# 25

# %%
synsets[24]
# Out:
# array([(array([[25]], dtype=uint8), array(['n02092339'], dtype='<U9'), array(['Weimaraner'], dtype='<U10'), array(['large breed of hound having a smooth greyish coat; originated in Germany'],
#              dtype='<U72'), array([[0]], dtype=uint8), array([], shape=(1, 0), dtype=uint8), array([[0]], dtype=uint8), array([[1300]], dtype=uint16))                                         ],
#       dtype=[('ILSVRC2012_ID', 'O'), ('WNID', 'O'), ('words', 'O'), ('gloss', 'O'), ('num_children', 'O'), ('children', 'O'), ('wordnet_height', 'O'), ('num_train_images', 'O')])

# %%
# Assuming your training images are stored in a directory where each subfolder is named by the wnid.
dataset_dir = "/scratch/data/imagenet/train"  # adjust this path as needed
img_label_mapping = {}

for wnid in os.listdir('/scratch/data/imagenet/train'):

    folder_path = os.path.join(dataset_dir, wnid)

    if not os.path.isdir(folder_path):
        continue
    label = wnid_to_label.get(wnid)
    # Only proceed if the wnid is in our mapping.
    if label is None:
        continue
    # Loop through each image in the subfolder.
    for img_file in os.listdir(folder_path):
        # Construct the full path for the image.
        img_path = os.path.join("train", wnid, img_file)
        img_label_mapping[img_path] = int(label)

# Step 4: Save the mapping as a JSON file.
with open('/scratch/data/imagenet/train.json', 'w') as f:
    json.dump(img_label_mapping, f, indent=4)

print("JSON file '/scratch/data/imagenet/train.json' generated successfully.")
# Out:
# n02114712
# /scratch/data/imagenet/train/n02114712
# n02092339
# /scratch/data/imagenet/train/n02092339
# n03791053
# /scratch/data/imagenet/train/n03791053
# n02128385
# /scratch/data/imagenet/train/n02128385
# n04141076
# /scratch/data/imagenet/train/n04141076
# n03866082
# /scratch/data/imagenet/train/n03866082
# n01847000
# /scratch/data/imagenet/train/n01847000
# n04525305
# /scratch/data/imagenet/train/n04525305
# n01773797
# /scratch/data/imagenet/train/n01773797
# n02108000
# /scratch/data/imagenet/train/n02108000
# n04557648
# /scratch/data/imagenet/train/n04557648
# n10565667
# /scratch/data/imagenet/train/n10565667
# n04228054
# /scratch/data/imagenet/train/n04228054
# n03775071
# /scratch/data/imagenet/train/n03775071
# n02113186
# /scratch/data/imagenet/train/n02113186
# n02137549
# /scratch/data/imagenet/train/n02137549
# n03110669
# /scratch/data/imagenet/train/n03110669
# n02098413
# /scratch/data/imagenet/train/n02098413
# n02950826
# /scratch/data/imagenet/train/n02950826
# n02486261
# /scratch/data/imagenet/train/n02486261
# n04118538
# /scratch/data/imagenet/train/n04118538
# n03535780
# /scratch/data/imagenet/train/n03535780
# n09256479
# /scratch/data/imagenet/train/n09256479
# n03843555
# /scratch/data/imagenet/train/n03843555
# n01443537
# /scratch/data/imagenet/train/n01443537
# n04355933
# /scratch/data/imagenet/train/n04355933
# n01729977
# /scratch/data/imagenet/train/n01729977
# n03888605
# /scratch/data/imagenet/train/n03888605
# n04330267
# /scratch/data/imagenet/train/n04330267
# n01697457
# /scratch/data/imagenet/train/n01697457
# n03902125
# /scratch/data/imagenet/train/n03902125
# n02814860
# /scratch/data/imagenet/train/n02814860
# n02974003
# /scratch/data/imagenet/train/n02974003
# n03637318
# /scratch/data/imagenet/train/n03637318
# n02091134
# /scratch/data/imagenet/train/n02091134
# n02667093
# /scratch/data/imagenet/train/n02667093
# n02113712
# /scratch/data/imagenet/train/n02113712
# n02110806
# /scratch/data/imagenet/train/n02110806
# n02514041
# /scratch/data/imagenet/train/n02514041
# n02009912
# /scratch/data/imagenet/train/n02009912
# n07749582
# /scratch/data/imagenet/train/n07749582
# n09835506
# /scratch/data/imagenet/train/n09835506
# n04579432
# /scratch/data/imagenet/train/n04579432
# n03424325
# /scratch/data/imagenet/train/n03424325
# n02492660
# /scratch/data/imagenet/train/n02492660
# n03662601
# /scratch/data/imagenet/train/n03662601
# n02165456
# /scratch/data/imagenet/train/n02165456
# n03388549
# /scratch/data/imagenet/train/n03388549
# n07860988
# /scratch/data/imagenet/train/n07860988
# n03584829
# /scratch/data/imagenet/train/n03584829
# n03642806
# /scratch/data/imagenet/train/n03642806
# n03944341
# /scratch/data/imagenet/train/n03944341
# n02113978
# /scratch/data/imagenet/train/n02113978
# n04332243
# /scratch/data/imagenet/train/n04332243
# n02666196
# /scratch/data/imagenet/train/n02666196
# n04204347
# /scratch/data/imagenet/train/n04204347
# n02128757
# /scratch/data/imagenet/train/n02128757
# n04149813
# /scratch/data/imagenet/train/n04149813
# n04435653
# /scratch/data/imagenet/train/n04435653
# n02480855
# /scratch/data/imagenet/train/n02480855
# n01817953
# /scratch/data/imagenet/train/n01817953
# n04509417
# /scratch/data/imagenet/train/n04509417
# n03188531
# /scratch/data/imagenet/train/n03188531
# n07684084
# /scratch/data/imagenet/train/n07684084
# n02104029
# /scratch/data/imagenet/train/n02104029
# n01818515
# /scratch/data/imagenet/train/n01818515
# n09288635
# /scratch/data/imagenet/train/n09288635
# n02655020
# /scratch/data/imagenet/train/n02655020
# n03792972
# /scratch/data/imagenet/train/n03792972
# n03982430
# /scratch/data/imagenet/train/n03982430
# n01914609
# /scratch/data/imagenet/train/n01914609
# n02088094
# /scratch/data/imagenet/train/n02088094
# n04263257
# /scratch/data/imagenet/train/n04263257
# n03218198
# /scratch/data/imagenet/train/n03218198
# n03786901
# /scratch/data/imagenet/train/n03786901
# n02457408
# /scratch/data/imagenet/train/n02457408
# n02795169
# /scratch/data/imagenet/train/n02795169
# n03394916
# /scratch/data/imagenet/train/n03394916
# n02510455
# /scratch/data/imagenet/train/n02510455
# n02643566
# /scratch/data/imagenet/train/n02643566
# n02279972
# /scratch/data/imagenet/train/n02279972
# n03532672
# /scratch/data/imagenet/train/n03532672
# n03544143
# /scratch/data/imagenet/train/n03544143
# n02782093
# /scratch/data/imagenet/train/n02782093
# n03733805
# /scratch/data/imagenet/train/n03733805
# n03977966
# /scratch/data/imagenet/train/n03977966
# n03676483
# /scratch/data/imagenet/train/n03676483
# n02089867
# /scratch/data/imagenet/train/n02089867
# n02422106
# /scratch/data/imagenet/train/n02422106
# n01978287
# /scratch/data/imagenet/train/n01978287
# n12998815
# /scratch/data/imagenet/train/n12998815
# n01798484
# /scratch/data/imagenet/train/n01798484
# n03697007
# /scratch/data/imagenet/train/n03697007
# n01729322
# /scratch/data/imagenet/train/n01729322
# n03014705
# /scratch/data/imagenet/train/n03014705
# n04376876
# /scratch/data/imagenet/train/n04376876
# n03666591
# /scratch/data/imagenet/train/n03666591
# n02066245
# /scratch/data/imagenet/train/n02066245
# n04562935
# /scratch/data/imagenet/train/n04562935
# n04458633
# /scratch/data/imagenet/train/n04458633
# n07802026
# /scratch/data/imagenet/train/n07802026
# n02484975
# /scratch/data/imagenet/train/n02484975
# n01560419
# /scratch/data/imagenet/train/n01560419
# n01751748
# /scratch/data/imagenet/train/n01751748
# n03710193
# /scratch/data/imagenet/train/n03710193
# n03837869
# /scratch/data/imagenet/train/n03837869
# n07697537
# /scratch/data/imagenet/train/n07697537
# n02966687
# /scratch/data/imagenet/train/n02966687
# n03776460
# /scratch/data/imagenet/train/n03776460
# n03970156
# /scratch/data/imagenet/train/n03970156
# n02640242
# /scratch/data/imagenet/train/n02640242
# n03950228
# /scratch/data/imagenet/train/n03950228
# n04485082
# /scratch/data/imagenet/train/n04485082
# n02917067
# /scratch/data/imagenet/train/n02917067
# n02229544
# /scratch/data/imagenet/train/n02229544
# n02892767
# /scratch/data/imagenet/train/n02892767
# n02219486
# /scratch/data/imagenet/train/n02219486
# n07711569
# /scratch/data/imagenet/train/n07711569
# n03220513
# /scratch/data/imagenet/train/n03220513
# n02422699
# /scratch/data/imagenet/train/n02422699
# n02012849
# /scratch/data/imagenet/train/n02012849
# n09468604
# /scratch/data/imagenet/train/n09468604
# n02979186
# /scratch/data/imagenet/train/n02979186
# n01806567
# /scratch/data/imagenet/train/n01806567
# n03272562
# /scratch/data/imagenet/train/n03272562
# n04070727
# /scratch/data/imagenet/train/n04070727
# n02799071
# /scratch/data/imagenet/train/n02799071
# n02971356
# /scratch/data/imagenet/train/n02971356
# n07875152
# /scratch/data/imagenet/train/n07875152
# n02233338
# /scratch/data/imagenet/train/n02233338
# n12057211
# /scratch/data/imagenet/train/n12057211
# n01828970
# /scratch/data/imagenet/train/n01828970
# n02107574
# /scratch/data/imagenet/train/n02107574
# n03485407
# /scratch/data/imagenet/train/n03485407
# n06785654
# /scratch/data/imagenet/train/n06785654
# n03690938
# /scratch/data/imagenet/train/n03690938
# n03089624
# /scratch/data/imagenet/train/n03089624
# n03065424
# /scratch/data/imagenet/train/n03065424
# n02033041
# /scratch/data/imagenet/train/n02033041
# n02487347
# /scratch/data/imagenet/train/n02487347
# n02120079
# /scratch/data/imagenet/train/n02120079
# n07720875
# /scratch/data/imagenet/train/n07720875
# n07718472
# /scratch/data/imagenet/train/n07718472
# n04049303
# /scratch/data/imagenet/train/n04049303
# n02099429
# /scratch/data/imagenet/train/n02099429
# n02361337
# /scratch/data/imagenet/train/n02361337
# n03623198
# /scratch/data/imagenet/train/n03623198
# n02123597
# /scratch/data/imagenet/train/n02123597
# n01484850
# /scratch/data/imagenet/train/n01484850
# n03445924
# /scratch/data/imagenet/train/n03445924
# n03838899
# /scratch/data/imagenet/train/n03838899
# n02445715
# /scratch/data/imagenet/train/n02445715
# n03916031
# /scratch/data/imagenet/train/n03916031
# n04209133
# /scratch/data/imagenet/train/n04209133
# n01695060
# /scratch/data/imagenet/train/n01695060
# n02441942
# /scratch/data/imagenet/train/n02441942
# n01688243
# /scratch/data/imagenet/train/n01688243
# n12985857
# /scratch/data/imagenet/train/n12985857
# n02708093
# /scratch/data/imagenet/train/n02708093
# n02102480
# /scratch/data/imagenet/train/n02102480
# n03781244
# /scratch/data/imagenet/train/n03781244
# n02102040
# /scratch/data/imagenet/train/n02102040
# n02777292
# /scratch/data/imagenet/train/n02777292
# n06359193
# /scratch/data/imagenet/train/n06359193
# n03347037
# /scratch/data/imagenet/train/n03347037
# n02727426
# /scratch/data/imagenet/train/n02727426
# n01753488
# /scratch/data/imagenet/train/n01753488
# n02494079
# /scratch/data/imagenet/train/n02494079
# n01784675
# /scratch/data/imagenet/train/n01784675
# n02105251
# /scratch/data/imagenet/train/n02105251
# n02110958
# /scratch/data/imagenet/train/n02110958
# n04153751
# /scratch/data/imagenet/train/n04153751
# n04005630
# /scratch/data/imagenet/train/n04005630
# n02018207
# /scratch/data/imagenet/train/n02018207
# n02965783
# /scratch/data/imagenet/train/n02965783
# n03379051
# /scratch/data/imagenet/train/n03379051
# n02077923
# /scratch/data/imagenet/train/n02077923
# n01968897
# /scratch/data/imagenet/train/n01968897
# n04209239
# /scratch/data/imagenet/train/n04209239
# n03937543
# /scratch/data/imagenet/train/n03937543
# n12267677
# /scratch/data/imagenet/train/n12267677
# n01537544
# /scratch/data/imagenet/train/n01537544
# n02823750
# /scratch/data/imagenet/train/n02823750
# n03314780
# /scratch/data/imagenet/train/n03314780
# n04311004
# /scratch/data/imagenet/train/n04311004
# n04467665
# /scratch/data/imagenet/train/n04467665
# n02444819
# /scratch/data/imagenet/train/n02444819
# n02088238
# /scratch/data/imagenet/train/n02088238
# n04325704
# /scratch/data/imagenet/train/n04325704
# n02112018
# /scratch/data/imagenet/train/n02112018
# n04040759
# /scratch/data/imagenet/train/n04040759
# n03670208
# /scratch/data/imagenet/train/n03670208
# n04404412
# /scratch/data/imagenet/train/n04404412
# n04532670
# /scratch/data/imagenet/train/n04532670
# n07831146
# /scratch/data/imagenet/train/n07831146
# n07873807
# /scratch/data/imagenet/train/n07873807
# n02091032
# /scratch/data/imagenet/train/n02091032
# n02093256
# /scratch/data/imagenet/train/n02093256
# n02346627
# /scratch/data/imagenet/train/n02346627
# n13044778
# /scratch/data/imagenet/train/n13044778
# n02088364
# /scratch/data/imagenet/train/n02088364
# n02843684
# /scratch/data/imagenet/train/n02843684
# n02769748
# /scratch/data/imagenet/train/n02769748
# n02825657
# /scratch/data/imagenet/train/n02825657
# n04086273
# /scratch/data/imagenet/train/n04086273
# n02916936
# /scratch/data/imagenet/train/n02916936
# n03854065
# /scratch/data/imagenet/train/n03854065
# n04487081
# /scratch/data/imagenet/train/n04487081
# n02096294
# /scratch/data/imagenet/train/n02096294
# n02096585
# /scratch/data/imagenet/train/n02096585
# n04041544
# /scratch/data/imagenet/train/n04041544
# n02814533
# /scratch/data/imagenet/train/n02814533
# n04317175
# /scratch/data/imagenet/train/n04317175
# n02906734
# /scratch/data/imagenet/train/n02906734
# n02113799
# /scratch/data/imagenet/train/n02113799
# n02787622
# /scratch/data/imagenet/train/n02787622
# n03271574
# /scratch/data/imagenet/train/n03271574
# n01917289
# /scratch/data/imagenet/train/n01917289
# n02113023
# /scratch/data/imagenet/train/n02113023
# n04259630
# /scratch/data/imagenet/train/n04259630
# n02094114
# /scratch/data/imagenet/train/n02094114
# n04423845
# /scratch/data/imagenet/train/n04423845
# n03720891
# /scratch/data/imagenet/train/n03720891
# n04118776
# /scratch/data/imagenet/train/n04118776
# n04074963
# /scratch/data/imagenet/train/n04074963
# n04090263
# /scratch/data/imagenet/train/n04090263
# n02747177
# /scratch/data/imagenet/train/n02747177
# n03891251
# /scratch/data/imagenet/train/n03891251
# n04462240
# /scratch/data/imagenet/train/n04462240
# n12620546
# /scratch/data/imagenet/train/n12620546
# n02793495
# /scratch/data/imagenet/train/n02793495
# n02134418
# /scratch/data/imagenet/train/n02134418
# n03930313
# /scratch/data/imagenet/train/n03930313
# n02325366
# /scratch/data/imagenet/train/n02325366
# n04265275
# /scratch/data/imagenet/train/n04265275
# n02978881
# /scratch/data/imagenet/train/n02978881
# n03063599
# /scratch/data/imagenet/train/n03063599
# n02909870
# /scratch/data/imagenet/train/n02909870
# n07579787
# /scratch/data/imagenet/train/n07579787
# n02281787
# /scratch/data/imagenet/train/n02281787
# n03126707
# /scratch/data/imagenet/train/n03126707
# n03617480
# /scratch/data/imagenet/train/n03617480
# n02396427
# /scratch/data/imagenet/train/n02396427
# n02109961
# /scratch/data/imagenet/train/n02109961
# n03594734
# /scratch/data/imagenet/train/n03594734
# n02363005
# /scratch/data/imagenet/train/n02363005
# n02108422
# /scratch/data/imagenet/train/n02108422
# n02808440
# /scratch/data/imagenet/train/n02808440
# n03942813
# /scratch/data/imagenet/train/n03942813
# n02999410
# /scratch/data/imagenet/train/n02999410
# n01910747
# /scratch/data/imagenet/train/n01910747
# n03223299
# /scratch/data/imagenet/train/n03223299
# n02791270
# /scratch/data/imagenet/train/n02791270
# n01829413
# /scratch/data/imagenet/train/n01829413
# n03602883
# /scratch/data/imagenet/train/n03602883
# n02676566
# /scratch/data/imagenet/train/n02676566
# n02105412
# /scratch/data/imagenet/train/n02105412
# n03388043
# /scratch/data/imagenet/train/n03388043
# n09246464
# /scratch/data/imagenet/train/n09246464
# n04136333
# /scratch/data/imagenet/train/n04136333
# n03179701
# /scratch/data/imagenet/train/n03179701
# n03476991
# /scratch/data/imagenet/train/n03476991
# n02095570
# /scratch/data/imagenet/train/n02095570
# n01820546
# /scratch/data/imagenet/train/n01820546
# n04356056
# /scratch/data/imagenet/train/n04356056
# n02099712
# /scratch/data/imagenet/train/n02099712
# n02100236
# /scratch/data/imagenet/train/n02100236
# n02037110
# /scratch/data/imagenet/train/n02037110
# n04275548
# /scratch/data/imagenet/train/n04275548
# n02791124
# /scratch/data/imagenet/train/n02791124
# n03832673
# /scratch/data/imagenet/train/n03832673
# n02089973
# /scratch/data/imagenet/train/n02089973
# n01944390
# /scratch/data/imagenet/train/n01944390
# n04131690
# /scratch/data/imagenet/train/n04131690
# n03814639
# /scratch/data/imagenet/train/n03814639
# n02114367
# /scratch/data/imagenet/train/n02114367
# n04296562
# /scratch/data/imagenet/train/n04296562
# n01694178
# /scratch/data/imagenet/train/n01694178
# n02111277
# /scratch/data/imagenet/train/n02111277
# n02342885
# /scratch/data/imagenet/train/n02342885
# n02111129
# /scratch/data/imagenet/train/n02111129
# n02085936
# /scratch/data/imagenet/train/n02085936
# n03485794
# /scratch/data/imagenet/train/n03485794
# n03496892
# /scratch/data/imagenet/train/n03496892
# n02115641
# /scratch/data/imagenet/train/n02115641
# n02114548
# /scratch/data/imagenet/train/n02114548
# n03384352
# /scratch/data/imagenet/train/n03384352
# n02167151
# /scratch/data/imagenet/train/n02167151
# n02869837
# /scratch/data/imagenet/train/n02869837
# n07920052
# /scratch/data/imagenet/train/n07920052
# n03929855
# /scratch/data/imagenet/train/n03929855
# n02111500
# /scratch/data/imagenet/train/n02111500
# n01843065
# /scratch/data/imagenet/train/n01843065
# n02085620
# /scratch/data/imagenet/train/n02085620
# n02097130
# /scratch/data/imagenet/train/n02097130
# n04286575
# /scratch/data/imagenet/train/n04286575
# n03452741
# /scratch/data/imagenet/train/n03452741
# n04487394
# /scratch/data/imagenet/train/n04487394
# n02504013
# /scratch/data/imagenet/train/n02504013
# n03075370
# /scratch/data/imagenet/train/n03075370
# n02107908
# /scratch/data/imagenet/train/n02107908
# n02488702
# /scratch/data/imagenet/train/n02488702
# n04589890
# /scratch/data/imagenet/train/n04589890
# n02817516
# /scratch/data/imagenet/train/n02817516
# n01558993
# /scratch/data/imagenet/train/n01558993
# n01955084
# /scratch/data/imagenet/train/n01955084
# n04239074
# /scratch/data/imagenet/train/n04239074
# n02106030
# /scratch/data/imagenet/train/n02106030
# n01950731
# /scratch/data/imagenet/train/n01950731
# n02823428
# /scratch/data/imagenet/train/n02823428
# n01983481
# /scratch/data/imagenet/train/n01983481
# n02437312
# /scratch/data/imagenet/train/n02437312
# n04004767
# /scratch/data/imagenet/train/n04004767
# n01518878
# /scratch/data/imagenet/train/n01518878
# n02364673
# /scratch/data/imagenet/train/n02364673
# n01630670
# /scratch/data/imagenet/train/n01630670
# n03393912
# /scratch/data/imagenet/train/n03393912
# n03476684
# /scratch/data/imagenet/train/n03476684
# n02017213
# /scratch/data/imagenet/train/n02017213
# n02117135
# /scratch/data/imagenet/train/n02117135
# n03291819
# /scratch/data/imagenet/train/n03291819
# n04254680
# /scratch/data/imagenet/train/n04254680
# n02113624
# /scratch/data/imagenet/train/n02113624
# n04370456
# /scratch/data/imagenet/train/n04370456
# n03763968
# /scratch/data/imagenet/train/n03763968
# n03954731
# /scratch/data/imagenet/train/n03954731
# n04429376
# /scratch/data/imagenet/train/n04429376
# n02412080
# /scratch/data/imagenet/train/n02412080
# n04019541
# /scratch/data/imagenet/train/n04019541
# n04525038
# /scratch/data/imagenet/train/n04525038
# n02730930
# /scratch/data/imagenet/train/n02730930
# n03742115
# /scratch/data/imagenet/train/n03742115
# n01985128
# /scratch/data/imagenet/train/n01985128
# n07930864
# /scratch/data/imagenet/train/n07930864
# n04536866
# /scratch/data/imagenet/train/n04536866
# n03633091
# /scratch/data/imagenet/train/n03633091
# n03868863
# /scratch/data/imagenet/train/n03868863
# n01797886
# /scratch/data/imagenet/train/n01797886
# n02091635
# /scratch/data/imagenet/train/n02091635
# n10148035
# /scratch/data/imagenet/train/n10148035
# n03146219
# /scratch/data/imagenet/train/n03146219
# n04548362
# /scratch/data/imagenet/train/n04548362
# n02095314
# /scratch/data/imagenet/train/n02095314
# n02138441
# /scratch/data/imagenet/train/n02138441
# n03967562
# /scratch/data/imagenet/train/n03967562
# n11879895
# /scratch/data/imagenet/train/n11879895
# n02837789
# /scratch/data/imagenet/train/n02837789
# n03692522
# /scratch/data/imagenet/train/n03692522
# n03590841
# /scratch/data/imagenet/train/n03590841
# n02086646
# /scratch/data/imagenet/train/n02086646
# n02804414
# /scratch/data/imagenet/train/n02804414
# n02326432
# /scratch/data/imagenet/train/n02326432
# n02105855
# /scratch/data/imagenet/train/n02105855
# n04591157
# /scratch/data/imagenet/train/n04591157
# n07584110
# /scratch/data/imagenet/train/n07584110
# n02106662
# /scratch/data/imagenet/train/n02106662
# n03208938
# /scratch/data/imagenet/train/n03208938
# n02992529
# /scratch/data/imagenet/train/n02992529
# n03494278
# /scratch/data/imagenet/train/n03494278
# n01687978
# /scratch/data/imagenet/train/n01687978
# n04344873
# /scratch/data/imagenet/train/n04344873
# n02119022
# /scratch/data/imagenet/train/n02119022
# n01855672
# /scratch/data/imagenet/train/n01855672
# n01728572
# /scratch/data/imagenet/train/n01728572
# n04347754
# /scratch/data/imagenet/train/n04347754
# n02087394
# /scratch/data/imagenet/train/n02087394
# n03796401
# /scratch/data/imagenet/train/n03796401
# n02106550
# /scratch/data/imagenet/train/n02106550
# n04592741
# /scratch/data/imagenet/train/n04592741
# n03187595
# /scratch/data/imagenet/train/n03187595
# n02447366
# /scratch/data/imagenet/train/n02447366
# n03372029
# /scratch/data/imagenet/train/n03372029
# n07583066
# /scratch/data/imagenet/train/n07583066
# n02804610
# /scratch/data/imagenet/train/n02804610
# n03000134
# /scratch/data/imagenet/train/n03000134
# n02099601
# /scratch/data/imagenet/train/n02099601
# n07753592
# /scratch/data/imagenet/train/n07753592
# n02094258
# /scratch/data/imagenet/train/n02094258
# n04584207
# /scratch/data/imagenet/train/n04584207
# n04371774
# /scratch/data/imagenet/train/n04371774
# n04127249
# /scratch/data/imagenet/train/n04127249
# n03938244
# /scratch/data/imagenet/train/n03938244
# n01860187
# /scratch/data/imagenet/train/n01860187
# n03673027
# /scratch/data/imagenet/train/n03673027
# n07714990
# /scratch/data/imagenet/train/n07714990
# n07716358
# /scratch/data/imagenet/train/n07716358
# n04599235
# /scratch/data/imagenet/train/n04599235
# n03483316
# /scratch/data/imagenet/train/n03483316
# n02002724
# /scratch/data/imagenet/train/n02002724
# n03947888
# /scratch/data/imagenet/train/n03947888
# n02087046
# /scratch/data/imagenet/train/n02087046
# n04380533
# /scratch/data/imagenet/train/n04380533
# n04392985
# /scratch/data/imagenet/train/n04392985
# n01677366
# /scratch/data/imagenet/train/n01677366
# n07717556
# /scratch/data/imagenet/train/n07717556
# n04335435
# /scratch/data/imagenet/train/n04335435
# n03016953
# /scratch/data/imagenet/train/n03016953
# n03877845
# /scratch/data/imagenet/train/n03877845
# n02130308
# /scratch/data/imagenet/train/n02130308
# n02123159
# /scratch/data/imagenet/train/n02123159
# n03876231
# /scratch/data/imagenet/train/n03876231
# n03495258
# /scratch/data/imagenet/train/n03495258
# n03344393
# /scratch/data/imagenet/train/n03344393
# n02086240
# /scratch/data/imagenet/train/n02086240
# n03770439
# /scratch/data/imagenet/train/n03770439
# n03874293
# /scratch/data/imagenet/train/n03874293
# n04505470
# /scratch/data/imagenet/train/n04505470
# n04008634
# /scratch/data/imagenet/train/n04008634
# n02090622
# /scratch/data/imagenet/train/n02090622
# n09428293
# /scratch/data/imagenet/train/n09428293
# n04418357
# /scratch/data/imagenet/train/n04418357
# n03134739
# /scratch/data/imagenet/train/n03134739
# n02116738
# /scratch/data/imagenet/train/n02116738
# n01735189
# /scratch/data/imagenet/train/n01735189
# n02093991
# /scratch/data/imagenet/train/n02093991
# n01748264
# /scratch/data/imagenet/train/n01748264
# n07695742
# /scratch/data/imagenet/train/n07695742
# n02074367
# /scratch/data/imagenet/train/n02074367
# n02840245
# /scratch/data/imagenet/train/n02840245
# n04192698
# /scratch/data/imagenet/train/n04192698
# n02090721
# /scratch/data/imagenet/train/n02090721
# n02115913
# /scratch/data/imagenet/train/n02115913
# n03980874
# /scratch/data/imagenet/train/n03980874
# n04067472
# /scratch/data/imagenet/train/n04067472
# n02009229
# /scratch/data/imagenet/train/n02009229
# n02090379
# /scratch/data/imagenet/train/n02090379
# n03085013
# /scratch/data/imagenet/train/n03085013
# n07753113
# /scratch/data/imagenet/train/n07753113
# n03761084
# /scratch/data/imagenet/train/n03761084
# n02879718
# /scratch/data/imagenet/train/n02879718
# n03733281
# /scratch/data/imagenet/train/n03733281
# n02704792
# /scratch/data/imagenet/train/n02704792
# n02797295
# /scratch/data/imagenet/train/n02797295
# n07742313
# /scratch/data/imagenet/train/n07742313
# n04523525
# /scratch/data/imagenet/train/n04523525
# n07730033
# /scratch/data/imagenet/train/n07730033
# n02011460
# /scratch/data/imagenet/train/n02011460
# n04310018
# /scratch/data/imagenet/train/n04310018
# n09193705
# /scratch/data/imagenet/train/n09193705
# n02190166
# /scratch/data/imagenet/train/n02190166
# n04235860
# /scratch/data/imagenet/train/n04235860
# n07760859
# /scratch/data/imagenet/train/n07760859
# n04355338
# /scratch/data/imagenet/train/n04355338
# n03063689
# /scratch/data/imagenet/train/n03063689
# n02107142
# /scratch/data/imagenet/train/n02107142
# n04399382
# /scratch/data/imagenet/train/n04399382
# n02098105
# /scratch/data/imagenet/train/n02098105
# n03630383
# /scratch/data/imagenet/train/n03630383
# n03775546
# /scratch/data/imagenet/train/n03775546
# n02106382
# /scratch/data/imagenet/train/n02106382
# n04613696
# /scratch/data/imagenet/train/n04613696
# n02107683
# /scratch/data/imagenet/train/n02107683
# n02226429
# /scratch/data/imagenet/train/n02226429
# n03895866
# /scratch/data/imagenet/train/n03895866
# n02071294
# /scratch/data/imagenet/train/n02071294
# n03773504
# /scratch/data/imagenet/train/n03773504
# n03599486
# /scratch/data/imagenet/train/n03599486
# n04146614
# /scratch/data/imagenet/train/n04146614
# n01531178
# /scratch/data/imagenet/train/n01531178
# n03998194
# /scratch/data/imagenet/train/n03998194
# n04479046
# /scratch/data/imagenet/train/n04479046
# n01692333
# /scratch/data/imagenet/train/n01692333
# n03131574
# /scratch/data/imagenet/train/n03131574
# n03240683
# /scratch/data/imagenet/train/n03240683
# n02093859
# /scratch/data/imagenet/train/n02093859
# n02097658
# /scratch/data/imagenet/train/n02097658
# n02408429
# /scratch/data/imagenet/train/n02408429
# n02802426
# /scratch/data/imagenet/train/n02802426
# n02493793
# /scratch/data/imagenet/train/n02493793
# n04398044
# /scratch/data/imagenet/train/n04398044
# n04350905
# /scratch/data/imagenet/train/n04350905
# n03873416
# /scratch/data/imagenet/train/n03873416
# n02834397
# /scratch/data/imagenet/train/n02834397
# n03018349
# /scratch/data/imagenet/train/n03018349
# n03958227
# /scratch/data/imagenet/train/n03958227
# n02790996
# /scratch/data/imagenet/train/n02790996
# n04243546
# /scratch/data/imagenet/train/n04243546
# n03127747
# /scratch/data/imagenet/train/n03127747
# n02536864
# /scratch/data/imagenet/train/n02536864
# n03598930
# /scratch/data/imagenet/train/n03598930
# n02013706
# /scratch/data/imagenet/train/n02013706
# n04357314
# /scratch/data/imagenet/train/n04357314
# n02391049
# /scratch/data/imagenet/train/n02391049
# n02114855
# /scratch/data/imagenet/train/n02114855
# n01629819
# /scratch/data/imagenet/train/n01629819
# n02058221
# /scratch/data/imagenet/train/n02058221
# n03444034
# /scratch/data/imagenet/train/n03444034
# n04179913
# /scratch/data/imagenet/train/n04179913
# n03787032
# /scratch/data/imagenet/train/n03787032
# n03400231
# /scratch/data/imagenet/train/n03400231
# n04254120
# /scratch/data/imagenet/train/n04254120
# n03788365
# /scratch/data/imagenet/train/n03788365
# n02395406
# /scratch/data/imagenet/train/n02395406
# n02492035
# /scratch/data/imagenet/train/n02492035
# n02093647
# /scratch/data/imagenet/train/n02093647
# n02356798
# /scratch/data/imagenet/train/n02356798
# n03976657
# /scratch/data/imagenet/train/n03976657
# n02102973
# /scratch/data/imagenet/train/n02102973
# n02101006
# /scratch/data/imagenet/train/n02101006
# n03127925
# /scratch/data/imagenet/train/n03127925
# n04238763
# /scratch/data/imagenet/train/n04238763
# n02094433
# /scratch/data/imagenet/train/n02094433
# n03443371
# /scratch/data/imagenet/train/n03443371
# n02051845
# /scratch/data/imagenet/train/n02051845
# n01644900
# /scratch/data/imagenet/train/n01644900
# n02119789
# /scratch/data/imagenet/train/n02119789
# n03891332
# /scratch/data/imagenet/train/n03891332
# n04033901
# /scratch/data/imagenet/train/n04033901
# n02105641
# /scratch/data/imagenet/train/n02105641
# n01833805
# /scratch/data/imagenet/train/n01833805
# n01644373
# /scratch/data/imagenet/train/n01644373
# n03355925
# /scratch/data/imagenet/train/n03355925
# n01773157
# /scratch/data/imagenet/train/n01773157
# n02127052
# /scratch/data/imagenet/train/n02127052
# n02098286
# /scratch/data/imagenet/train/n02098286
# n02493509
# /scratch/data/imagenet/train/n02493509
# n01749939
# /scratch/data/imagenet/train/n01749939
# n04456115
# /scratch/data/imagenet/train/n04456115
# n03109150
# /scratch/data/imagenet/train/n03109150
# n03041632
# /scratch/data/imagenet/train/n03041632
# n01739381
# /scratch/data/imagenet/train/n01739381
# n03100240
# /scratch/data/imagenet/train/n03100240
# n04579145
# /scratch/data/imagenet/train/n04579145
# n04604644
# /scratch/data/imagenet/train/n04604644
# n04039381
# /scratch/data/imagenet/train/n04039381
# n02206856
# /scratch/data/imagenet/train/n02206856
# n02133161
# /scratch/data/imagenet/train/n02133161
# n02606052
# /scratch/data/imagenet/train/n02606052
# n02786058
# /scratch/data/imagenet/train/n02786058
# n03445777
# /scratch/data/imagenet/train/n03445777
# n04493381
# /scratch/data/imagenet/train/n04493381
# n02321529
# /scratch/data/imagenet/train/n02321529
# n02109047
# /scratch/data/imagenet/train/n02109047
# n01514859
# /scratch/data/imagenet/train/n01514859
# n02807133
# /scratch/data/imagenet/train/n02807133
# n04116512
# /scratch/data/imagenet/train/n04116512
# n09421951
# /scratch/data/imagenet/train/n09421951
# n02841315
# /scratch/data/imagenet/train/n02841315
# n02109525
# /scratch/data/imagenet/train/n02109525
# n02056570
# /scratch/data/imagenet/train/n02056570
# n03717622
# /scratch/data/imagenet/train/n03717622
# n02101388
# /scratch/data/imagenet/train/n02101388
# n01514668
# /scratch/data/imagenet/train/n01514668
# n02027492
# /scratch/data/imagenet/train/n02027492
# n03709823
# /scratch/data/imagenet/train/n03709823
# n02687172
# /scratch/data/imagenet/train/n02687172
# n03868242
# /scratch/data/imagenet/train/n03868242
# n02028035
# /scratch/data/imagenet/train/n02028035
# n04372370
# /scratch/data/imagenet/train/n04372370
# n02100583
# /scratch/data/imagenet/train/n02100583
# n01756291
# /scratch/data/imagenet/train/n01756291
# n07693725
# /scratch/data/imagenet/train/n07693725
# n02454379
# /scratch/data/imagenet/train/n02454379
# n01631663
# /scratch/data/imagenet/train/n01631663
# n03482405
# /scratch/data/imagenet/train/n03482405
# n06874185
# /scratch/data/imagenet/train/n06874185
# n02112350
# /scratch/data/imagenet/train/n02112350
# n03724870
# /scratch/data/imagenet/train/n03724870
# n02102177
# /scratch/data/imagenet/train/n02102177
# n01980166
# /scratch/data/imagenet/train/n01980166
# n03180011
# /scratch/data/imagenet/train/n03180011
# n03376595
# /scratch/data/imagenet/train/n03376595
# n02086910
# /scratch/data/imagenet/train/n02086910
# n04229816
# /scratch/data/imagenet/train/n04229816
# n01806143
# /scratch/data/imagenet/train/n01806143
# n03216828
# /scratch/data/imagenet/train/n03216828
# n02699494
# /scratch/data/imagenet/train/n02699494
# n02397096
# /scratch/data/imagenet/train/n02397096
# n03992509
# /scratch/data/imagenet/train/n03992509
# n01737021
# /scratch/data/imagenet/train/n01737021
# n02129165
# /scratch/data/imagenet/train/n02129165
# n02776631
# /scratch/data/imagenet/train/n02776631
# n04552348
# /scratch/data/imagenet/train/n04552348
# n02280649
# /scratch/data/imagenet/train/n02280649
# n03297495
# /scratch/data/imagenet/train/n03297495
# n03733131
# /scratch/data/imagenet/train/n03733131
# n03729826
# /scratch/data/imagenet/train/n03729826
# n02259212
# /scratch/data/imagenet/train/n02259212
# n04264628
# /scratch/data/imagenet/train/n04264628
# n03196217
# /scratch/data/imagenet/train/n03196217
# n03840681
# /scratch/data/imagenet/train/n03840681
# n02089078
# /scratch/data/imagenet/train/n02089078
# n01689811
# /scratch/data/imagenet/train/n01689811
# n02108089
# /scratch/data/imagenet/train/n02108089
# n01698640
# /scratch/data/imagenet/train/n01698640
# n03337140
# /scratch/data/imagenet/train/n03337140
# n03661043
# /scratch/data/imagenet/train/n03661043
# n03201208
# /scratch/data/imagenet/train/n03201208
# n07747607
# /scratch/data/imagenet/train/n07747607
# n03995372
# /scratch/data/imagenet/train/n03995372
# n02165105
# /scratch/data/imagenet/train/n02165105
# n01819313
# /scratch/data/imagenet/train/n01819313
# n07614500
# /scratch/data/imagenet/train/n07614500
# n13052670
# /scratch/data/imagenet/train/n13052670
# n02988304
# /scratch/data/imagenet/train/n02988304
# n04606251
# /scratch/data/imagenet/train/n04606251
# n01632458
# /scratch/data/imagenet/train/n01632458
# n03160309
# /scratch/data/imagenet/train/n03160309
# n01986214
# /scratch/data/imagenet/train/n01986214
# n07892512
# /scratch/data/imagenet/train/n07892512
# n02104365
# /scratch/data/imagenet/train/n02104365
# n01924916
# /scratch/data/imagenet/train/n01924916
# n04277352
# /scratch/data/imagenet/train/n04277352
# n03124170
# /scratch/data/imagenet/train/n03124170
# n03976467
# /scratch/data/imagenet/train/n03976467
# n07718747
# /scratch/data/imagenet/train/n07718747
# n02672831
# /scratch/data/imagenet/train/n02672831
# n02276258
# /scratch/data/imagenet/train/n02276258
# n01978455
# /scratch/data/imagenet/train/n01978455
# n04367480
# /scratch/data/imagenet/train/n04367480
# n04532106
# /scratch/data/imagenet/train/n04532106
# n04542943
# /scratch/data/imagenet/train/n04542943
# n02134084
# /scratch/data/imagenet/train/n02134084
# n02389026
# /scratch/data/imagenet/train/n02389026
# n01685808
# /scratch/data/imagenet/train/n01685808
# n02169497
# /scratch/data/imagenet/train/n02169497
# n02860847
# /scratch/data/imagenet/train/n02860847
# n01667778
# /scratch/data/imagenet/train/n01667778
# n02788148
# /scratch/data/imagenet/train/n02788148
# n03095699
# /scratch/data/imagenet/train/n03095699
# n01728920
# /scratch/data/imagenet/train/n01728920
# n04326547
# /scratch/data/imagenet/train/n04326547
# n02417914
# /scratch/data/imagenet/train/n02417914
# n03956157
# /scratch/data/imagenet/train/n03956157
# n03887697
# /scratch/data/imagenet/train/n03887697
# n04201297
# /scratch/data/imagenet/train/n04201297
# n02101556
# /scratch/data/imagenet/train/n02101556
# n01632777
# /scratch/data/imagenet/train/n01632777
# n15075141
# /scratch/data/imagenet/train/n15075141
# n03125729
# /scratch/data/imagenet/train/n03125729
# n01669191
# /scratch/data/imagenet/train/n01669191
# n04033995
# /scratch/data/imagenet/train/n04033995
# n02398521
# /scratch/data/imagenet/train/n02398521
# n03032252
# /scratch/data/imagenet/train/n03032252
# n04252225
# /scratch/data/imagenet/train/n04252225
# n03467068
# /scratch/data/imagenet/train/n03467068
# n01534433
# /scratch/data/imagenet/train/n01534433
# n03903868
# /scratch/data/imagenet/train/n03903868
# n01990800
# /scratch/data/imagenet/train/n01990800
# n01667114
# /scratch/data/imagenet/train/n01667114
# n03450230
# /scratch/data/imagenet/train/n03450230
# n02977058
# /scratch/data/imagenet/train/n02977058
# n07697313
# /scratch/data/imagenet/train/n07697313
# n01807496
# /scratch/data/imagenet/train/n01807496
# n07248320
# /scratch/data/imagenet/train/n07248320
# n02231487
# /scratch/data/imagenet/train/n02231487
# n03527444
# /scratch/data/imagenet/train/n03527444
# n02110627
# /scratch/data/imagenet/train/n02110627
# n02948072
# /scratch/data/imagenet/train/n02948072
# n03657121
# /scratch/data/imagenet/train/n03657121
# n02870880
# /scratch/data/imagenet/train/n02870880
# n02268443
# /scratch/data/imagenet/train/n02268443
# n03788195
# /scratch/data/imagenet/train/n03788195
# n02859443
# /scratch/data/imagenet/train/n02859443
# n03792782
# /scratch/data/imagenet/train/n03792782
# n04111531
# /scratch/data/imagenet/train/n04111531
# n02086079
# /scratch/data/imagenet/train/n02086079
# n04328186
# /scratch/data/imagenet/train/n04328186
# n02481823
# /scratch/data/imagenet/train/n02481823
# n03133878
# /scratch/data/imagenet/train/n03133878
# n02110185
# /scratch/data/imagenet/train/n02110185
# n03529860
# /scratch/data/imagenet/train/n03529860
# n04141327
# /scratch/data/imagenet/train/n04141327
# n02132136
# /scratch/data/imagenet/train/n02132136
# n02894605
# /scratch/data/imagenet/train/n02894605
# n04065272
# /scratch/data/imagenet/train/n04065272
# n03259280
# /scratch/data/imagenet/train/n03259280
# n02835271
# /scratch/data/imagenet/train/n02835271
# n07880968
# /scratch/data/imagenet/train/n07880968
# n02980441
# /scratch/data/imagenet/train/n02980441
# n02749479
# /scratch/data/imagenet/train/n02749479
# n03534580
# /scratch/data/imagenet/train/n03534580
# n02951358
# /scratch/data/imagenet/train/n02951358
# n04482393
# /scratch/data/imagenet/train/n04482393
# n02504458
# /scratch/data/imagenet/train/n02504458
# n04507155
# /scratch/data/imagenet/train/n04507155
# n03028079
# /scratch/data/imagenet/train/n03028079
# n04515003
# /scratch/data/imagenet/train/n04515003
# n01742172
# /scratch/data/imagenet/train/n01742172
# n04346328
# /scratch/data/imagenet/train/n04346328
# n04476259
# /scratch/data/imagenet/train/n04476259
# n03584254
# /scratch/data/imagenet/train/n03584254
# n01491361
# /scratch/data/imagenet/train/n01491361
# n03884397
# /scratch/data/imagenet/train/n03884397
# n01592084
# /scratch/data/imagenet/train/n01592084
# n03991062
# /scratch/data/imagenet/train/n03991062
# n04501370
# /scratch/data/imagenet/train/n04501370
# n01981276
# /scratch/data/imagenet/train/n01981276
# n02096051
# /scratch/data/imagenet/train/n02096051
# n03871628
# /scratch/data/imagenet/train/n03871628
# n02088466
# /scratch/data/imagenet/train/n02088466
# n02423022
# /scratch/data/imagenet/train/n02423022
# n04023962
# /scratch/data/imagenet/train/n04023962
# n02403003
# /scratch/data/imagenet/train/n02403003
# n02091831
# /scratch/data/imagenet/train/n02091831
# n04152593
# /scratch/data/imagenet/train/n04152593
# n12144580
# /scratch/data/imagenet/train/n12144580
# n02093428
# /scratch/data/imagenet/train/n02093428
# n02105056
# /scratch/data/imagenet/train/n02105056
# n02125311
# /scratch/data/imagenet/train/n02125311
# n01824575
# /scratch/data/imagenet/train/n01824575
# n04517823
# /scratch/data/imagenet/train/n04517823
# n01682714
# /scratch/data/imagenet/train/n01682714
# n02480495
# /scratch/data/imagenet/train/n02480495
# n03793489
# /scratch/data/imagenet/train/n03793489
# n01774750
# /scratch/data/imagenet/train/n01774750
# n02018795
# /scratch/data/imagenet/train/n02018795
# n02128925
# /scratch/data/imagenet/train/n02128925
# n02690373
# /scratch/data/imagenet/train/n02690373
# n03000247
# /scratch/data/imagenet/train/n03000247
# n02099267
# /scratch/data/imagenet/train/n02099267
# n02111889
# /scratch/data/imagenet/train/n02111889
# n02483708
# /scratch/data/imagenet/train/n02483708
# n02091244
# /scratch/data/imagenet/train/n02091244
# n03794056
# /scratch/data/imagenet/train/n03794056
# n01734418
# /scratch/data/imagenet/train/n01734418
# n13133613
# /scratch/data/imagenet/train/n13133613
# n02120505
# /scratch/data/imagenet/train/n02120505
# n07716906
# /scratch/data/imagenet/train/n07716906
# n03983396
# /scratch/data/imagenet/train/n03983396
# n04560804
# /scratch/data/imagenet/train/n04560804
# n04285008
# /scratch/data/imagenet/train/n04285008
# n04389033
# /scratch/data/imagenet/train/n04389033
# n02783161
# /scratch/data/imagenet/train/n02783161
# n02410509
# /scratch/data/imagenet/train/n02410509
# n01641577
# /scratch/data/imagenet/train/n01641577
# n01580077
# /scratch/data/imagenet/train/n01580077
# n04273569
# /scratch/data/imagenet/train/n04273569
# n01530575
# /scratch/data/imagenet/train/n01530575
# n02328150
# /scratch/data/imagenet/train/n02328150
# n01768244
# /scratch/data/imagenet/train/n01768244
# n03777568
# /scratch/data/imagenet/train/n03777568
# n07932039
# /scratch/data/imagenet/train/n07932039
# n03026506
# /scratch/data/imagenet/train/n03026506
# n03249569
# /scratch/data/imagenet/train/n03249569
# n03404251
# /scratch/data/imagenet/train/n03404251
# n01532829
# /scratch/data/imagenet/train/n01532829
# n02794156
# /scratch/data/imagenet/train/n02794156
# n02025239
# /scratch/data/imagenet/train/n02025239
# n02268853
# /scratch/data/imagenet/train/n02268853
# n07836838
# /scratch/data/imagenet/train/n07836838
# n03345487
# /scratch/data/imagenet/train/n03345487
# n07590611
# /scratch/data/imagenet/train/n07590611
# n07753275
# /scratch/data/imagenet/train/n07753275
# n04251144
# /scratch/data/imagenet/train/n04251144
# n01704323
# /scratch/data/imagenet/train/n01704323
# n02939185
# /scratch/data/imagenet/train/n02939185
# n02910353
# /scratch/data/imagenet/train/n02910353
# n04428191
# /scratch/data/imagenet/train/n04428191
# n01872401
# /scratch/data/imagenet/train/n01872401
# n02100735
# /scratch/data/imagenet/train/n02100735
# n03045698
# /scratch/data/imagenet/train/n03045698
# n02815834
# /scratch/data/imagenet/train/n02815834
# n01498041
# /scratch/data/imagenet/train/n01498041
# n03000684
# /scratch/data/imagenet/train/n03000684
# n02002556
# /scratch/data/imagenet/train/n02002556
# n01744401
# /scratch/data/imagenet/train/n01744401
# n02490219
# /scratch/data/imagenet/train/n02490219
# n01773549
# /scratch/data/imagenet/train/n01773549
# n03447721
# /scratch/data/imagenet/train/n03447721
# n13040303
# /scratch/data/imagenet/train/n13040303
# n03785016
# /scratch/data/imagenet/train/n03785016
# n03388183
# /scratch/data/imagenet/train/n03388183
# n04483307
# /scratch/data/imagenet/train/n04483307
# n04099969
# /scratch/data/imagenet/train/n04099969
# n04548280
# /scratch/data/imagenet/train/n04548280
# n03538406
# /scratch/data/imagenet/train/n03538406
# n04125021
# /scratch/data/imagenet/train/n04125021
# n03017168
# /scratch/data/imagenet/train/n03017168
# n03908714
# /scratch/data/imagenet/train/n03908714
# n03459775
# /scratch/data/imagenet/train/n03459775
# n03804744
# /scratch/data/imagenet/train/n03804744
# n04258138
# /scratch/data/imagenet/train/n04258138
# n03062245
# /scratch/data/imagenet/train/n03062245
# n04371430
# /scratch/data/imagenet/train/n04371430
# n03770679
# /scratch/data/imagenet/train/n03770679
# n02107312
# /scratch/data/imagenet/train/n02107312
# n04037443
# /scratch/data/imagenet/train/n04037443
# n09332890
# /scratch/data/imagenet/train/n09332890
# n03325584
# /scratch/data/imagenet/train/n03325584
# n02981792
# /scratch/data/imagenet/train/n02981792
# n03492542
# /scratch/data/imagenet/train/n03492542
# n01945685
# /scratch/data/imagenet/train/n01945685
# n02092002
# /scratch/data/imagenet/train/n02092002
# n02088632
# /scratch/data/imagenet/train/n02088632
# n02877765
# /scratch/data/imagenet/train/n02877765
# n01740131
# /scratch/data/imagenet/train/n01740131
# n03710637
# /scratch/data/imagenet/train/n03710637
# n01843383
# /scratch/data/imagenet/train/n01843383
# n01582220
# /scratch/data/imagenet/train/n01582220
# n02319095
# /scratch/data/imagenet/train/n02319095
# n03920288
# /scratch/data/imagenet/train/n03920288
# n01873310
# /scratch/data/imagenet/train/n01873310
# n04009552
# /scratch/data/imagenet/train/n04009552
# n04133789
# /scratch/data/imagenet/train/n04133789
# n01616318
# /scratch/data/imagenet/train/n01616318
# n07565083
# /scratch/data/imagenet/train/n07565083
# n06794110
# /scratch/data/imagenet/train/n06794110
# n04553703
# /scratch/data/imagenet/train/n04553703
# n07714571
# /scratch/data/imagenet/train/n07714571
# n02112137
# /scratch/data/imagenet/train/n02112137
# n02500267
# /scratch/data/imagenet/train/n02500267
# n03250847
# /scratch/data/imagenet/train/n03250847
# n04442312
# /scratch/data/imagenet/train/n04442312
# n01930112
# /scratch/data/imagenet/train/n01930112
# n01883070
# /scratch/data/imagenet/train/n01883070
# n02927161
# /scratch/data/imagenet/train/n02927161
# n02963159
# /scratch/data/imagenet/train/n02963159
# n01664065
# /scratch/data/imagenet/train/n01664065
# n02489166
# /scratch/data/imagenet/train/n02489166
# n03888257
# /scratch/data/imagenet/train/n03888257
# n03658185
# /scratch/data/imagenet/train/n03658185
# n07768694
# /scratch/data/imagenet/train/n07768694
# n03481172
# /scratch/data/imagenet/train/n03481172
# n02871525
# /scratch/data/imagenet/train/n02871525
# n03498962
# /scratch/data/imagenet/train/n03498962
# n02124075
# /scratch/data/imagenet/train/n02124075
# n02110063
# /scratch/data/imagenet/train/n02110063
# n03874599
# /scratch/data/imagenet/train/n03874599
# n01608432
# /scratch/data/imagenet/train/n01608432
# n02085782
# /scratch/data/imagenet/train/n02085782
# n07717410
# /scratch/data/imagenet/train/n07717410
# n02096437
# /scratch/data/imagenet/train/n02096437
# n03857828
# /scratch/data/imagenet/train/n03857828
# n09399592
# /scratch/data/imagenet/train/n09399592
# n04270147
# /scratch/data/imagenet/train/n04270147
# n02108551
# /scratch/data/imagenet/train/n02108551
# n04254777
# /scratch/data/imagenet/train/n04254777
# n04443257
# /scratch/data/imagenet/train/n04443257
# n02123394
# /scratch/data/imagenet/train/n02123394
# n03478589
# /scratch/data/imagenet/train/n03478589
# n04147183
# /scratch/data/imagenet/train/n04147183
# n04409515
# /scratch/data/imagenet/train/n04409515
# n01770393
# /scratch/data/imagenet/train/n01770393
# n01877812
# /scratch/data/imagenet/train/n01877812
# n01855032
# /scratch/data/imagenet/train/n01855032
# n03197337
# /scratch/data/imagenet/train/n03197337
# n07615774
# /scratch/data/imagenet/train/n07615774
# n03803284
# /scratch/data/imagenet/train/n03803284
# n02443484
# /scratch/data/imagenet/train/n02443484
# n01943899
# /scratch/data/imagenet/train/n01943899
# n03595614
# /scratch/data/imagenet/train/n03595614
# n04141975
# /scratch/data/imagenet/train/n04141975
# n03825788
# /scratch/data/imagenet/train/n03825788
# n01984695
# /scratch/data/imagenet/train/n01984695
# n02096177
# /scratch/data/imagenet/train/n02096177
# n03710721
# /scratch/data/imagenet/train/n03710721
# n02106166
# /scratch/data/imagenet/train/n02106166
# n04522168
# /scratch/data/imagenet/train/n04522168
# n11939491
# /scratch/data/imagenet/train/n11939491
# n02992211
# /scratch/data/imagenet/train/n02992211
# n02497673
# /scratch/data/imagenet/train/n02497673
# n07734744
# /scratch/data/imagenet/train/n07734744
# n06596364
# /scratch/data/imagenet/train/n06596364
# n02093754
# /scratch/data/imagenet/train/n02093754
# n03290653
# /scratch/data/imagenet/train/n03290653
# n03743016
# /scratch/data/imagenet/train/n03743016
# n02486410
# /scratch/data/imagenet/train/n02486410
# n02112706
# /scratch/data/imagenet/train/n02112706
# n02692877
# /scratch/data/imagenet/train/n02692877
# n02442845
# /scratch/data/imagenet/train/n02442845
# n03447447
# /scratch/data/imagenet/train/n03447447
# n03706229
# /scratch/data/imagenet/train/n03706229
# n04366367
# /scratch/data/imagenet/train/n04366367
# n02641379
# /scratch/data/imagenet/train/n02641379
# n04550184
# /scratch/data/imagenet/train/n04550184
# n02437616
# /scratch/data/imagenet/train/n02437616
# n02443114
# /scratch/data/imagenet/train/n02443114
# n02883205
# /scratch/data/imagenet/train/n02883205
# n02930766
# /scratch/data/imagenet/train/n02930766
# n02808304
# /scratch/data/imagenet/train/n02808304
# n02102318
# /scratch/data/imagenet/train/n02102318
# n03961711
# /scratch/data/imagenet/train/n03961711
# n02669723
# /scratch/data/imagenet/train/n02669723
# n03649909
# /scratch/data/imagenet/train/n03649909
# n01494475
# /scratch/data/imagenet/train/n01494475
# n02483362
# /scratch/data/imagenet/train/n02483362
# n02174001
# /scratch/data/imagenet/train/n02174001
# n01776313
# /scratch/data/imagenet/train/n01776313
# n03691459
# /scratch/data/imagenet/train/n03691459
# n02097298
# /scratch/data/imagenet/train/n02097298
# n04208210
# /scratch/data/imagenet/train/n04208210
# n03680355
# /scratch/data/imagenet/train/n03680355
# n04311174
# /scratch/data/imagenet/train/n04311174
# n03769881
# /scratch/data/imagenet/train/n03769881
# n02236044
# /scratch/data/imagenet/train/n02236044
# n01622779
# /scratch/data/imagenet/train/n01622779
# n02168699
# /scratch/data/imagenet/train/n02168699
# n02526121
# /scratch/data/imagenet/train/n02526121
# n02415577
# /scratch/data/imagenet/train/n02415577
# n02105162
# /scratch/data/imagenet/train/n02105162
# n09229709
# /scratch/data/imagenet/train/n09229709
# n01795545
# /scratch/data/imagenet/train/n01795545
# n04204238
# /scratch/data/imagenet/train/n04204238
# n03207743
# /scratch/data/imagenet/train/n03207743
# n02264363
# /scratch/data/imagenet/train/n02264363
# n01614925
# /scratch/data/imagenet/train/n01614925
# n03425413
# /scratch/data/imagenet/train/n03425413
# n02281406
# /scratch/data/imagenet/train/n02281406
# n02317335
# /scratch/data/imagenet/train/n02317335
# n02123045
# /scratch/data/imagenet/train/n02123045
# n01665541
# /scratch/data/imagenet/train/n01665541
# n03814906
# /scratch/data/imagenet/train/n03814906
# n02865351
# /scratch/data/imagenet/train/n02865351
# n02091467
# /scratch/data/imagenet/train/n02091467
# n04540053
# /scratch/data/imagenet/train/n04540053
# n01871265
# /scratch/data/imagenet/train/n01871265
# n04336792
# /scratch/data/imagenet/train/n04336792
# n03207941
# /scratch/data/imagenet/train/n03207941
# n04461696
# /scratch/data/imagenet/train/n04461696
# n02129604
# /scratch/data/imagenet/train/n02129604
# n02100877
# /scratch/data/imagenet/train/n02100877
# n02108915
# /scratch/data/imagenet/train/n02108915
# n03930630
# /scratch/data/imagenet/train/n03930630
# n07613480
# /scratch/data/imagenet/train/n07613480
# n02509815
# /scratch/data/imagenet/train/n02509815
# n02172182
# /scratch/data/imagenet/train/n02172182
# n01775062
# /scratch/data/imagenet/train/n01775062
# n03933933
# /scratch/data/imagenet/train/n03933933
# n02895154
# /scratch/data/imagenet/train/n02895154
# n12768682
# /scratch/data/imagenet/train/n12768682
# n04266014
# /scratch/data/imagenet/train/n04266014
# n03255030
# /scratch/data/imagenet/train/n03255030
# n03935335
# /scratch/data/imagenet/train/n03935335
# n03457902
# /scratch/data/imagenet/train/n03457902
# n04120489
# /scratch/data/imagenet/train/n04120489
# n02951585
# /scratch/data/imagenet/train/n02951585
# n03924679
# /scratch/data/imagenet/train/n03924679
# n03047690
# /scratch/data/imagenet/train/n03047690
# n04154565
# /scratch/data/imagenet/train/n04154565
# n02006656
# /scratch/data/imagenet/train/n02006656
# n03124043
# /scratch/data/imagenet/train/n03124043
# n03594945
# /scratch/data/imagenet/train/n03594945
# n02110341
# /scratch/data/imagenet/train/n02110341
# n03929660
# /scratch/data/imagenet/train/n03929660
# n07715103
# /scratch/data/imagenet/train/n07715103
# n03841143
# /scratch/data/imagenet/train/n03841143
# n09472597
# /scratch/data/imagenet/train/n09472597
# n04591713
# /scratch/data/imagenet/train/n04591713
# n03530642
# /scratch/data/imagenet/train/n03530642
# n01796340
# /scratch/data/imagenet/train/n01796340
# n04612504
# /scratch/data/imagenet/train/n04612504
# n03777754
# /scratch/data/imagenet/train/n03777754
# n03782006
# /scratch/data/imagenet/train/n03782006
# n03764736
# /scratch/data/imagenet/train/n03764736
# n04252077
# /scratch/data/imagenet/train/n04252077
# n01755581
# /scratch/data/imagenet/train/n01755581
# n02105505
# /scratch/data/imagenet/train/n02105505
# n02966193
# /scratch/data/imagenet/train/n02966193
# n03042490
# /scratch/data/imagenet/train/n03042490
# n01496331
# /scratch/data/imagenet/train/n01496331
# n04447861
# /scratch/data/imagenet/train/n04447861
# n02607072
# /scratch/data/imagenet/train/n02607072
# n04069434
# /scratch/data/imagenet/train/n04069434
# n04554684
# /scratch/data/imagenet/train/n04554684
# n02095889
# /scratch/data/imagenet/train/n02095889
# n13054560
# /scratch/data/imagenet/train/n13054560
# n02256656
# /scratch/data/imagenet/train/n02256656
# n04026417
# /scratch/data/imagenet/train/n04026417
# n01693334
# /scratch/data/imagenet/train/n01693334
# n03899768
# /scratch/data/imagenet/train/n03899768
# n03721384
# /scratch/data/imagenet/train/n03721384
# n03877472
# /scratch/data/imagenet/train/n03877472
# n02097209
# /scratch/data/imagenet/train/n02097209
# n04200800
# /scratch/data/imagenet/train/n04200800
# n01882714
# /scratch/data/imagenet/train/n01882714
# n04044716
# /scratch/data/imagenet/train/n04044716
# n03908618
# /scratch/data/imagenet/train/n03908618
# n03627232
# /scratch/data/imagenet/train/n03627232
# n03461385
# /scratch/data/imagenet/train/n03461385
# n01770081
# /scratch/data/imagenet/train/n01770081
# n03272010
# /scratch/data/imagenet/train/n03272010
# n04162706
# /scratch/data/imagenet/train/n04162706
# n04465501
# /scratch/data/imagenet/train/n04465501
# n04597913
# /scratch/data/imagenet/train/n04597913
# n02701002
# /scratch/data/imagenet/train/n02701002
# n07871810
# /scratch/data/imagenet/train/n07871810
# n01601694
# /scratch/data/imagenet/train/n01601694
# n02177972
# /scratch/data/imagenet/train/n02177972
# n07754684
# /scratch/data/imagenet/train/n07754684
# n02488291
# /scratch/data/imagenet/train/n02488291
# n02277742
# /scratch/data/imagenet/train/n02277742
# n01774384
# /scratch/data/imagenet/train/n01774384
# n04596742
# /scratch/data/imagenet/train/n04596742
# n02892201
# /scratch/data/imagenet/train/n02892201
# n01440764
# /scratch/data/imagenet/train/n01440764
# n03141823
# /scratch/data/imagenet/train/n03141823
# n13037406
# /scratch/data/imagenet/train/n13037406
# n04486054
# /scratch/data/imagenet/train/n04486054
# n04081281
# /scratch/data/imagenet/train/n04081281
# n04590129
# /scratch/data/imagenet/train/n04590129
# n04417672
# /scratch/data/imagenet/train/n04417672
# n01675722
# /scratch/data/imagenet/train/n01675722
# n07745940
# /scratch/data/imagenet/train/n07745940
# n03417042
# /scratch/data/imagenet/train/n03417042
# n03759954
# /scratch/data/imagenet/train/n03759954
# n02097047
# /scratch/data/imagenet/train/n02097047
# n02097474
# /scratch/data/imagenet/train/n02097474
# n02007558
# /scratch/data/imagenet/train/n02007558
# n02099849
# /scratch/data/imagenet/train/n02099849
# JSON file '/scratch/data/imagenet/train.json' generated successfully.

# %%
img_label_mapping
# Out:
# {'train/n02114712/n02114712_16558.JPEG': 439,
#  'train/n02114712/n02114712_18198.JPEG': 439,
#  'train/n02114712/n02114712_23650.JPEG': 439,
#  'train/n02114712/n02114712_21167.JPEG': 439,
#  'train/n02114712/n02114712_23819.JPEG': 439,
#  'train/n02114712/n02114712_4755.JPEG': 439,
#  'train/n02114712/n02114712_11148.JPEG': 439,
#  'train/n02114712/n02114712_20341.JPEG': 439,
#  'train/n02114712/n02114712_23078.JPEG': 439,
#  'train/n02114712/n02114712_22556.JPEG': 439,
#  'train/n02114712/n02114712_9617.JPEG': 439,
#  'train/n02114712/n02114712_837.JPEG': 439,
#  'train/n02114712/n02114712_584.JPEG': 439,
#  'train/n02114712/n02114712_15938.JPEG': 439,
#  'train/n02114712/n02114712_17588.JPEG': 439,
#  'train/n02114712/n02114712_17039.JPEG': 439,
#  'train/n02114712/n02114712_2047.JPEG': 439,
#  'train/n02114712/n02114712_16891.JPEG': 439,
#  'train/n02114712/n02114712_18999.JPEG': 439,
#  'train/n02114712/n02114712_1263.JPEG': 439,
#  'train/n02114712/n02114712_4248.JPEG': 439,
#  'train/n02114712/n02114712_16240.JPEG': 439,
#  'train/n02114712/n02114712_19935.JPEG': 439,
#  'train/n02114712/n02114712_17642.JPEG': 439,
#  'train/n02114712/n02114712_1495.JPEG': 439,
#  'train/n02114712/n02114712_3463.JPEG': 439,
#  'train/n02114712/n02114712_18694.JPEG': 439,
#  'train/n02114712/n02114712_9701.JPEG': 439,
#  'train/n02114712/n02114712_15272.JPEG': 439,
#  'train/n02114712/n02114712_21217.JPEG': 439,
#  'train/n02114712/n02114712_14185.JPEG': 439,
#  'train/n02114712/n02114712_21059.JPEG': 439,
#  'train/n02114712/n02114712_13912.JPEG': 439,
#  'train/n02114712/n02114712_23794.JPEG': 439,
#  'train/n02114712/n02114712_18400.JPEG': 439,
#  'train/n02114712/n02114712_14154.JPEG': 439,
#  'train/n02114712/n02114712_21023.JPEG': 439,
#  'train/n02114712/n02114712_12699.JPEG': 439,
#  'train/n02114712/n02114712_16982.JPEG': 439,
#  'train/n02114712/n02114712_2459.JPEG': 439,
#  'train/n02114712/n02114712_4380.JPEG': 439,
#  'train/n02114712/n02114712_15936.JPEG': 439,
#  'train/n02114712/n02114712_16479.JPEG': 439,
#  'train/n02114712/n02114712_17329.JPEG': 439,
#  'train/n02114712/n02114712_18877.JPEG': 439,
#  'train/n02114712/n02114712_7569.JPEG': 439,
#  'train/n02114712/n02114712_5012.JPEG': 439,
#  'train/n02114712/n02114712_13999.JPEG': 439,
#  'train/n02114712/n02114712_15391.JPEG': 439,
#  'train/n02114712/n02114712_2854.JPEG': 439,
#  'train/n02114712/n02114712_13061.JPEG': 439,
#  'train/n02114712/n02114712_2614.JPEG': 439,
#  'train/n02114712/n02114712_8237.JPEG': 439,
#  'train/n02114712/n02114712_21576.JPEG': 439,
#  'train/n02114712/n02114712_6927.JPEG': 439,
#  'train/n02114712/n02114712_23682.JPEG': 439,
#  'train/n02114712/n02114712_20069.JPEG': 439,
#  'train/n02114712/n02114712_18271.JPEG': 439,
#  'train/n02114712/n02114712_5194.JPEG': 439,
#  'train/n02114712/n02114712_18287.JPEG': 439,
#  'train/n02114712/n02114712_3545.JPEG': 439,
#  'train/n02114712/n02114712_15903.JPEG': 439,
#  'train/n02114712/n02114712_1293.JPEG': 439,
#  'train/n02114712/n02114712_17361.JPEG': 439,
#  'train/n02114712/n02114712_4834.JPEG': 439,
#  'train/n02114712/n02114712_18118.JPEG': 439,
#  'train/n02114712/n02114712_18186.JPEG': 439,
#  'train/n02114712/n02114712_10029.JPEG': 439,
#  'train/n02114712/n02114712_5032.JPEG': 439,
#  'train/n02114712/n02114712_20349.JPEG': 439,
#  'train/n02114712/n02114712_4250.JPEG': 439,
#  'train/n02114712/n02114712_9838.JPEG': 439,
#  'train/n02114712/n02114712_6644.JPEG': 439,
#  'train/n02114712/n02114712_15679.JPEG': 439,
#  'train/n02114712/n02114712_19719.JPEG': 439,
#  'train/n02114712/n02114712_3767.JPEG': 439,
#  'train/n02114712/n02114712_578.JPEG': 439,
#  'train/n02114712/n02114712_15853.JPEG': 439,
#  'train/n02114712/n02114712_1534.JPEG': 439,
#  'train/n02114712/n02114712_3887.JPEG': 439,
#  'train/n02114712/n02114712_17510.JPEG': 439,
#  'train/n02114712/n02114712_4513.JPEG': 439,
#  'train/n02114712/n02114712_19597.JPEG': 439,
#  'train/n02114712/n02114712_10080.JPEG': 439,
#  'train/n02114712/n02114712_20110.JPEG': 439,
#  'train/n02114712/n02114712_4242.JPEG': 439,
#  'train/n02114712/n02114712_20512.JPEG': 439,
#  'train/n02114712/n02114712_1739.JPEG': 439,
#  'train/n02114712/n02114712_7089.JPEG': 439,
#  'train/n02114712/n02114712_14455.JPEG': 439,
#  'train/n02114712/n02114712_8978.JPEG': 439,
#  'train/n02114712/n02114712_22507.JPEG': 439,
#  'train/n02114712/n02114712_10394.JPEG': 439,
#  'train/n02114712/n02114712_15068.JPEG': 439,
#  'train/n02114712/n02114712_18777.JPEG': 439,
#  'train/n02114712/n02114712_8095.JPEG': 439,
#  'train/n02114712/n02114712_17747.JPEG': 439,
#  'train/n02114712/n02114712_20302.JPEG': 439,
#  'train/n02114712/n02114712_7445.JPEG': 439,
#  'train/n02114712/n02114712_22758.JPEG': 439,
#  'train/n02114712/n02114712_5533.JPEG': 439,
#  'train/n02114712/n02114712_11267.JPEG': 439,
#  'train/n02114712/n02114712_3128.JPEG': 439,
#  'train/n02114712/n02114712_23068.JPEG': 439,
#  'train/n02114712/n02114712_5287.JPEG': 439,
#  'train/n02114712/n02114712_2525.JPEG': 439,
#  'train/n02114712/n02114712_710.JPEG': 439,
#  'train/n02114712/n02114712_2670.JPEG': 439,
#  'train/n02114712/n02114712_442.JPEG': 439,
#  'train/n02114712/n02114712_20664.JPEG': 439,
#  'train/n02114712/n02114712_200.JPEG': 439,
#  'train/n02114712/n02114712_8936.JPEG': 439,
#  'train/n02114712/n02114712_2824.JPEG': 439,
#  'train/n02114712/n02114712_19097.JPEG': 439,
#  'train/n02114712/n02114712_3729.JPEG': 439,
#  'train/n02114712/n02114712_15888.JPEG': 439,
#  'train/n02114712/n02114712_22377.JPEG': 439,
#  'train/n02114712/n02114712_19414.JPEG': 439,
#  'train/n02114712/n02114712_9207.JPEG': 439,
#  'train/n02114712/n02114712_12177.JPEG': 439,
#  'train/n02114712/n02114712_3086.JPEG': 439,
#  'train/n02114712/n02114712_6603.JPEG': 439,
#  'train/n02114712/n02114712_17289.JPEG': 439,
#  'train/n02114712/n02114712_6722.JPEG': 439,
#  'train/n02114712/n02114712_22150.JPEG': 439,
#  'train/n02114712/n02114712_22791.JPEG': 439,
#  'train/n02114712/n02114712_3321.JPEG': 439,
#  'train/n02114712/n02114712_17065.JPEG': 439,
#  'train/n02114712/n02114712_18555.JPEG': 439,
#  'train/n02114712/n02114712_19960.JPEG': 439,
#  'train/n02114712/n02114712_9408.JPEG': 439,
#  'train/n02114712/n02114712_11462.JPEG': 439,
#  'train/n02114712/n02114712_19123.JPEG': 439,
#  'train/n02114712/n02114712_20390.JPEG': 439,
#  'train/n02114712/n02114712_16777.JPEG': 439,
#  'train/n02114712/n02114712_19201.JPEG': 439,
#  'train/n02114712/n02114712_1275.JPEG': 439,
#  'train/n02114712/n02114712_14199.JPEG': 439,
#  'train/n02114712/n02114712_15639.JPEG': 439,
#  'train/n02114712/n02114712_2016.JPEG': 439,
#  'train/n02114712/n02114712_22892.JPEG': 439,
#  'train/n02114712/n02114712_2533.JPEG': 439,
#  'train/n02114712/n02114712_17263.JPEG': 439,
#  'train/n02114712/n02114712_20568.JPEG': 439,
#  'train/n02114712/n02114712_7584.JPEG': 439,
#  'train/n02114712/n02114712_22782.JPEG': 439,
#  'train/n02114712/n02114712_16149.JPEG': 439,
#  'train/n02114712/n02114712_21965.JPEG': 439,
#  'train/n02114712/n02114712_15556.JPEG': 439,
#  'train/n02114712/n02114712_10563.JPEG': 439,
#  'train/n02114712/n02114712_21868.JPEG': 439,
#  'train/n02114712/n02114712_18340.JPEG': 439,
#  'train/n02114712/n02114712_8120.JPEG': 439,
#  'train/n02114712/n02114712_1448.JPEG': 439,
#  'train/n02114712/n02114712_19086.JPEG': 439,
#  'train/n02114712/n02114712_23471.JPEG': 439,
#  'train/n02114712/n02114712_6731.JPEG': 439,
#  'train/n02114712/n02114712_4157.JPEG': 439,
#  'train/n02114712/n02114712_5139.JPEG': 439,
#  'train/n02114712/n02114712_14702.JPEG': 439,
#  'train/n02114712/n02114712_16060.JPEG': 439,
#  'train/n02114712/n02114712_13267.JPEG': 439,
#  'train/n02114712/n02114712_15218.JPEG': 439,
#  'train/n02114712/n02114712_7314.JPEG': 439,
#  'train/n02114712/n02114712_18971.JPEG': 439,
#  'train/n02114712/n02114712_8584.JPEG': 439,
#  'train/n02114712/n02114712_17360.JPEG': 439,
#  'train/n02114712/n02114712_1941.JPEG': 439,
#  'train/n02114712/n02114712_14275.JPEG': 439,
#  'train/n02114712/n02114712_1388.JPEG': 439,
#  'train/n02114712/n02114712_9021.JPEG': 439,
#  'train/n02114712/n02114712_482.JPEG': 439,
#  'train/n02114712/n02114712_20007.JPEG': 439,
#  'train/n02114712/n02114712_19527.JPEG': 439,
#  'train/n02114712/n02114712_433.JPEG': 439,
#  'train/n02114712/n02114712_20418.JPEG': 439,
#  'train/n02114712/n02114712_5673.JPEG': 439,
#  'train/n02114712/n02114712_15358.JPEG': 439,
#  'train/n02114712/n02114712_23441.JPEG': 439,
#  'train/n02114712/n02114712_13256.JPEG': 439,
#  'train/n02114712/n02114712_21758.JPEG': 439,
#  'train/n02114712/n02114712_22830.JPEG': 439,
#  'train/n02114712/n02114712_19485.JPEG': 439,
#  'train/n02114712/n02114712_20452.JPEG': 439,
#  'train/n02114712/n02114712_3209.JPEG': 439,
#  'train/n02114712/n02114712_18257.JPEG': 439,
#  'train/n02114712/n02114712_8129.JPEG': 439,
#  'train/n02114712/n02114712_5302.JPEG': 439,
#  'train/n02114712/n02114712_16900.JPEG': 439,
#  'train/n02114712/n02114712_19236.JPEG': 439,
#  'train/n02114712/n02114712_17107.JPEG': 439,
#  'train/n02114712/n02114712_3362.JPEG': 439,
#  'train/n02114712/n02114712_3494.JPEG': 439,
#  'train/n02114712/n02114712_10346.JPEG': 439,
#  'train/n02114712/n02114712_13323.JPEG': 439,
#  'train/n02114712/n02114712_18588.JPEG': 439,
#  'train/n02114712/n02114712_1089.JPEG': 439,
#  'train/n02114712/n02114712_172.JPEG': 439,
#  'train/n02114712/n02114712_7210.JPEG': 439,
#  'train/n02114712/n02114712_3461.JPEG': 439,
#  'train/n02114712/n02114712_15887.JPEG': 439,
#  'train/n02114712/n02114712_19738.JPEG': 439,
#  'train/n02114712/n02114712_15380.JPEG': 439,
#  'train/n02114712/n02114712_3900.JPEG': 439,
#  'train/n02114712/n02114712_22504.JPEG': 439,
#  'train/n02114712/n02114712_18900.JPEG': 439,
#  'train/n02114712/n02114712_19463.JPEG': 439,
#  'train/n02114712/n02114712_2352.JPEG': 439,
#  'train/n02114712/n02114712_22257.JPEG': 439,
#  'train/n02114712/n02114712_16519.JPEG': 439,
#  'train/n02114712/n02114712_12444.JPEG': 439,
#  'train/n02114712/n02114712_19558.JPEG': 439,
#  'train/n02114712/n02114712_16630.JPEG': 439,
#  'train/n02114712/n02114712_4428.JPEG': 439,
#  'train/n02114712/n02114712_1133.JPEG': 439,
#  'train/n02114712/n02114712_1835.JPEG': 439,
#  'train/n02114712/n02114712_10184.JPEG': 439,
#  'train/n02114712/n02114712_15629.JPEG': 439,
#  'train/n02114712/n02114712_22148.JPEG': 439,
#  'train/n02114712/n02114712_7683.JPEG': 439,
#  'train/n02114712/n02114712_4067.JPEG': 439,
#  'train/n02114712/n02114712_6162.JPEG': 439,
#  'train/n02114712/n02114712_18827.JPEG': 439,
#  'train/n02114712/n02114712_3358.JPEG': 439,
#  'train/n02114712/n02114712_4496.JPEG': 439,
#  'train/n02114712/n02114712_16700.JPEG': 439,
#  'train/n02114712/n02114712_4573.JPEG': 439,
#  'train/n02114712/n02114712_20483.JPEG': 439,
#  'train/n02114712/n02114712_2160.JPEG': 439,
#  'train/n02114712/n02114712_6024.JPEG': 439,
#  'train/n02114712/n02114712_4708.JPEG': 439,
#  'train/n02114712/n02114712_19419.JPEG': 439,
#  'train/n02114712/n02114712_18356.JPEG': 439,
#  'train/n02114712/n02114712_16158.JPEG': 439,
#  'train/n02114712/n02114712_14380.JPEG': 439,
#  'train/n02114712/n02114712_23749.JPEG': 439,
#  'train/n02114712/n02114712_13251.JPEG': 439,
#  'train/n02114712/n02114712_2144.JPEG': 439,
#  'train/n02114712/n02114712_23419.JPEG': 439,
#  'train/n02114712/n02114712_21756.JPEG': 439,
#  'train/n02114712/n02114712_19861.JPEG': 439,
#  'train/n02114712/n02114712_19943.JPEG': 439,
#  'train/n02114712/n02114712_3011.JPEG': 439,
#  'train/n02114712/n02114712_16657.JPEG': 439,
#  'train/n02114712/n02114712_22406.JPEG': 439,
#  'train/n02114712/n02114712_9065.JPEG': 439,
#  'train/n02114712/n02114712_11070.JPEG': 439,
#  'train/n02114712/n02114712_999.JPEG': 439,
#  'train/n02114712/n02114712_4645.JPEG': 439,
#  'train/n02114712/n02114712_10526.JPEG': 439,
#  'train/n02114712/n02114712_4916.JPEG': 439,
#  'train/n02114712/n02114712_9302.JPEG': 439,
#  'train/n02114712/n02114712_21991.JPEG': 439,
#  'train/n02114712/n02114712_14528.JPEG': 439,
#  'train/n02114712/n02114712_24161.JPEG': 439,
#  'train/n02114712/n02114712_14688.JPEG': 439,
#  'train/n02114712/n02114712_1664.JPEG': 439,
#  'train/n02114712/n02114712_7117.JPEG': 439,
#  'train/n02114712/n02114712_3927.JPEG': 439,
#  'train/n02114712/n02114712_1098.JPEG': 439,
#  'train/n02114712/n02114712_356.JPEG': 439,
#  'train/n02114712/n02114712_12870.JPEG': 439,
#  'train/n02114712/n02114712_18904.JPEG': 439,
#  'train/n02114712/n02114712_6412.JPEG': 439,
#  'train/n02114712/n02114712_10935.JPEG': 439,
#  'train/n02114712/n02114712_17020.JPEG': 439,
#  'train/n02114712/n02114712_451.JPEG': 439,
#  'train/n02114712/n02114712_13089.JPEG': 439,
#  'train/n02114712/n02114712_13286.JPEG': 439,
#  'train/n02114712/n02114712_17541.JPEG': 439,
#  'train/n02114712/n02114712_606.JPEG': 439,
#  'train/n02114712/n02114712_17050.JPEG': 439,
#  'train/n02114712/n02114712_17844.JPEG': 439,
#  'train/n02114712/n02114712_12367.JPEG': 439,
#  'train/n02114712/n02114712_2289.JPEG': 439,
#  'train/n02114712/n02114712_19466.JPEG': 439,
#  'train/n02114712/n02114712_803.JPEG': 439,
#  'train/n02114712/n02114712_4339.JPEG': 439,
#  'train/n02114712/n02114712_13451.JPEG': 439,
#  'train/n02114712/n02114712_4326.JPEG': 439,
#  'train/n02114712/n02114712_9241.JPEG': 439,
#  'train/n02114712/n02114712_22114.JPEG': 439,
#  'train/n02114712/n02114712_6376.JPEG': 439,
#  'train/n02114712/n02114712_11615.JPEG': 439,
#  'train/n02114712/n02114712_1752.JPEG': 439,
#  'train/n02114712/n02114712_9852.JPEG': 439,
#  'train/n02114712/n02114712_8317.JPEG': 439,
#  'train/n02114712/n02114712_17514.JPEG': 439,
#  'train/n02114712/n02114712_17435.JPEG': 439,
#  'train/n02114712/n02114712_13052.JPEG': 439,
#  'train/n02114712/n02114712_18127.JPEG': 439,
#  'train/n02114712/n02114712_9230.JPEG': 439,
#  'train/n02114712/n02114712_6199.JPEG': 439,
#  'train/n02114712/n02114712_18411.JPEG': 439,
#  'train/n02114712/n02114712_6291.JPEG': 439,
#  'train/n02114712/n02114712_11806.JPEG': 439,
#  'train/n02114712/n02114712_2062.JPEG': 439,
#  'train/n02114712/n02114712_16306.JPEG': 439,
#  'train/n02114712/n02114712_23380.JPEG': 439,
#  'train/n02114712/n02114712_13366.JPEG': 439,
#  'train/n02114712/n02114712_11521.JPEG': 439,
#  'train/n02114712/n02114712_22418.JPEG': 439,
#  'train/n02114712/n02114712_9928.JPEG': 439,
#  'train/n02114712/n02114712_3811.JPEG': 439,
#  'train/n02114712/n02114712_7249.JPEG': 439,
#  'train/n02114712/n02114712_21517.JPEG': 439,
#  'train/n02114712/n02114712_2178.JPEG': 439,
#  'train/n02114712/n02114712_23894.JPEG': 439,
#  'train/n02114712/n02114712_20187.JPEG': 439,
#  'train/n02114712/n02114712_14873.JPEG': 439,
#  'train/n02114712/n02114712_16333.JPEG': 439,
#  'train/n02114712/n02114712_18273.JPEG': 439,
#  'train/n02114712/n02114712_17484.JPEG': 439,
#  'train/n02114712/n02114712_9751.JPEG': 439,
#  'train/n02114712/n02114712_1315.JPEG': 439,
#  'train/n02114712/n02114712_5157.JPEG': 439,
#  'train/n02114712/n02114712_5282.JPEG': 439,
#  'train/n02114712/n02114712_8623.JPEG': 439,
#  'train/n02114712/n02114712_2137.JPEG': 439,
#  'train/n02114712/n02114712_15566.JPEG': 439,
#  'train/n02114712/n02114712_3473.JPEG': 439,
#  'train/n02114712/n02114712_20787.JPEG': 439,
#  'train/n02114712/n02114712_23731.JPEG': 439,
#  'train/n02114712/n02114712_22275.JPEG': 439,
#  'train/n02114712/n02114712_17931.JPEG': 439,
#  'train/n02114712/n02114712_19627.JPEG': 439,
#  'train/n02114712/n02114712_21519.JPEG': 439,
#  'train/n02114712/n02114712_21958.JPEG': 439,
#  'train/n02114712/n02114712_10201.JPEG': 439,
#  'train/n02114712/n02114712_17311.JPEG': 439,
#  'train/n02114712/n02114712_15202.JPEG': 439,
#  'train/n02114712/n02114712_23487.JPEG': 439,
#  'train/n02114712/n02114712_9754.JPEG': 439,
#  'train/n02114712/n02114712_2280.JPEG': 439,
#  'train/n02114712/n02114712_22590.JPEG': 439,
#  'train/n02114712/n02114712_14310.JPEG': 439,
#  'train/n02114712/n02114712_20563.JPEG': 439,
#  'train/n02114712/n02114712_19921.JPEG': 439,
#  'train/n02114712/n02114712_21945.JPEG': 439,
#  'train/n02114712/n02114712_19047.JPEG': 439,
#  'train/n02114712/n02114712_19563.JPEG': 439,
#  'train/n02114712/n02114712_2194.JPEG': 439,
#  'train/n02114712/n02114712_115.JPEG': 439,
#  'train/n02114712/n02114712_11432.JPEG': 439,
#  'train/n02114712/n02114712_5138.JPEG': 439,
#  'train/n02114712/n02114712_13729.JPEG': 439,
#  'train/n02114712/n02114712_20464.JPEG': 439,
#  'train/n02114712/n02114712_15467.JPEG': 439,
#  'train/n02114712/n02114712_7786.JPEG': 439,
#  'train/n02114712/n02114712_20423.JPEG': 439,
#  'train/n02114712/n02114712_639.JPEG': 439,
#  'train/n02114712/n02114712_21777.JPEG': 439,
#  'train/n02114712/n02114712_2235.JPEG': 439,
#  'train/n02114712/n02114712_13682.JPEG': 439,
#  'train/n02114712/n02114712_22792.JPEG': 439,
#  'train/n02114712/n02114712_2887.JPEG': 439,
#  'train/n02114712/n02114712_23528.JPEG': 439,
#  'train/n02114712/n02114712_22289.JPEG': 439,
#  'train/n02114712/n02114712_23832.JPEG': 439,
#  'train/n02114712/n02114712_9768.JPEG': 439,
#  'train/n02114712/n02114712_21296.JPEG': 439,
#  'train/n02114712/n02114712_21776.JPEG': 439,
#  'train/n02114712/n02114712_23353.JPEG': 439,
#  'train/n02114712/n02114712_15292.JPEG': 439,
#  'train/n02114712/n02114712_21526.JPEG': 439,
#  'train/n02114712/n02114712_7452.JPEG': 439,
#  'train/n02114712/n02114712_6365.JPEG': 439,
#  'train/n02114712/n02114712_2819.JPEG': 439,
#  'train/n02114712/n02114712_17536.JPEG': 439,
#  'train/n02114712/n02114712_16773.JPEG': 439,
#  'train/n02114712/n02114712_21906.JPEG': 439,
#  'train/n02114712/n02114712_4899.JPEG': 439,
#  'train/n02114712/n02114712_6074.JPEG': 439,
#  'train/n02114712/n02114712_11025.JPEG': 439,
#  'train/n02114712/n02114712_19320.JPEG': 439,
#  'train/n02114712/n02114712_20405.JPEG': 439,
#  'train/n02114712/n02114712_11212.JPEG': 439,
#  'train/n02114712/n02114712_327.JPEG': 439,
#  'train/n02114712/n02114712_22557.JPEG': 439,
#  'train/n02114712/n02114712_22215.JPEG': 439,
#  'train/n02114712/n02114712_5099.JPEG': 439,
#  'train/n02114712/n02114712_6146.JPEG': 439,
#  'train/n02114712/n02114712_18351.JPEG': 439,
#  'train/n02114712/n02114712_21651.JPEG': 439,
#  'train/n02114712/n02114712_13816.JPEG': 439,
#  'train/n02114712/n02114712_22621.JPEG': 439,
#  'train/n02114712/n02114712_628.JPEG': 439,
#  'train/n02114712/n02114712_1456.JPEG': 439,
#  'train/n02114712/n02114712_15293.JPEG': 439,
#  'train/n02114712/n02114712_7334.JPEG': 439,
#  'train/n02114712/n02114712_18330.JPEG': 439,
#  'train/n02114712/n02114712_21918.JPEG': 439,
#  'train/n02114712/n02114712_13264.JPEG': 439,
#  'train/n02114712/n02114712_19475.JPEG': 439,
#  'train/n02114712/n02114712_15706.JPEG': 439,
#  'train/n02114712/n02114712_12099.JPEG': 439,
#  'train/n02114712/n02114712_5497.JPEG': 439,
#  'train/n02114712/n02114712_20749.JPEG': 439,
#  'train/n02114712/n02114712_21714.JPEG': 439,
#  'train/n02114712/n02114712_2131.JPEG': 439,
#  'train/n02114712/n02114712_22999.JPEG': 439,
#  'train/n02114712/n02114712_11905.JPEG': 439,
#  'train/n02114712/n02114712_14051.JPEG': 439,
#  'train/n02114712/n02114712_237.JPEG': 439,
#  'train/n02114712/n02114712_14958.JPEG': 439,
#  'train/n02114712/n02114712_21283.JPEG': 439,
#  'train/n02114712/n02114712_20140.JPEG': 439,
#  'train/n02114712/n02114712_7214.JPEG': 439,
#  'train/n02114712/n02114712_5141.JPEG': 439,
#  'train/n02114712/n02114712_17576.JPEG': 439,
#  'train/n02114712/n02114712_15626.JPEG': 439,
#  'train/n02114712/n02114712_13640.JPEG': 439,
#  'train/n02114712/n02114712_11607.JPEG': 439,
#  'train/n02114712/n02114712_10352.JPEG': 439,
#  'train/n02114712/n02114712_8406.JPEG': 439,
#  'train/n02114712/n02114712_16017.JPEG': 439,
#  'train/n02114712/n02114712_19986.JPEG': 439,
#  'train/n02114712/n02114712_9362.JPEG': 439,
#  'train/n02114712/n02114712_8235.JPEG': 439,
#  'train/n02114712/n02114712_4655.JPEG': 439,
#  'train/n02114712/n02114712_8657.JPEG': 439,
#  'train/n02114712/n02114712_16482.JPEG': 439,
#  'train/n02114712/n02114712_23210.JPEG': 439,
#  'train/n02114712/n02114712_10229.JPEG': 439,
#  'train/n02114712/n02114712_12729.JPEG': 439,
#  'train/n02114712/n02114712_15365.JPEG': 439,
#  'train/n02114712/n02114712_22583.JPEG': 439,
#  'train/n02114712/n02114712_13711.JPEG': 439,
#  'train/n02114712/n02114712_21580.JPEG': 439,
#  'train/n02114712/n02114712_4992.JPEG': 439,
#  'train/n02114712/n02114712_10473.JPEG': 439,
#  'train/n02114712/n02114712_18286.JPEG': 439,
#  'train/n02114712/n02114712_17919.JPEG': 439,
#  'train/n02114712/n02114712_16043.JPEG': 439,
#  'train/n02114712/n02114712_14035.JPEG': 439,
#  'train/n02114712/n02114712_9287.JPEG': 439,
#  'train/n02114712/n02114712_16512.JPEG': 439,
#  'train/n02114712/n02114712_21879.JPEG': 439,
#  'train/n02114712/n02114712_20127.JPEG': 439,
#  'train/n02114712/n02114712_23602.JPEG': 439,
#  'train/n02114712/n02114712_1598.JPEG': 439,
#  'train/n02114712/n02114712_17945.JPEG': 439,
#  'train/n02114712/n02114712_408.JPEG': 439,
#  'train/n02114712/n02114712_19417.JPEG': 439,
#  'train/n02114712/n02114712_14790.JPEG': 439,
#  'train/n02114712/n02114712_16061.JPEG': 439,
#  'train/n02114712/n02114712_7549.JPEG': 439,
#  'train/n02114712/n02114712_15419.JPEG': 439,
#  'train/n02114712/n02114712_972.JPEG': 439,
#  'train/n02114712/n02114712_16224.JPEG': 439,
#  'train/n02114712/n02114712_20831.JPEG': 439,
#  'train/n02114712/n02114712_17423.JPEG': 439,
#  'train/n02114712/n02114712_19072.JPEG': 439,
#  'train/n02114712/n02114712_3538.JPEG': 439,
#  'train/n02114712/n02114712_754.JPEG': 439,
#  'train/n02114712/n02114712_15408.JPEG': 439,
#  'train/n02114712/n02114712_17648.JPEG': 439,
#  'train/n02114712/n02114712_18377.JPEG': 439,
#  'train/n02114712/n02114712_3094.JPEG': 439,
#  'train/n02114712/n02114712_23064.JPEG': 439,
#  'train/n02114712/n02114712_16230.JPEG': 439,
#  'train/n02114712/n02114712_19641.JPEG': 439,
#  'train/n02114712/n02114712_2862.JPEG': 439,
#  'train/n02114712/n02114712_171.JPEG': 439,
#  'train/n02114712/n02114712_744.JPEG': 439,
#  'train/n02114712/n02114712_15585.JPEG': 439,
#  'train/n02114712/n02114712_19926.JPEG': 439,
#  'train/n02114712/n02114712_10839.JPEG': 439,
#  'train/n02114712/n02114712_13159.JPEG': 439,
#  'train/n02114712/n02114712_10880.JPEG': 439,
#  'train/n02114712/n02114712_19583.JPEG': 439,
#  'train/n02114712/n02114712_20771.JPEG': 439,
#  'train/n02114712/n02114712_23077.JPEG': 439,
#  'train/n02114712/n02114712_349.JPEG': 439,
#  'train/n02114712/n02114712_18833.JPEG': 439,
#  'train/n02114712/n02114712_12487.JPEG': 439,
#  'train/n02114712/n02114712_22890.JPEG': 439,
#  'train/n02114712/n02114712_3589.JPEG': 439,
#  'train/n02114712/n02114712_334.JPEG': 439,
#  'train/n02114712/n02114712_16666.JPEG': 439,
#  'train/n02114712/n02114712_19006.JPEG': 439,
#  'train/n02114712/n02114712_3458.JPEG': 439,
#  'train/n02114712/n02114712_13090.JPEG': 439,
#  'train/n02114712/n02114712_18290.JPEG': 439,
#  'train/n02114712/n02114712_21564.JPEG': 439,
#  'train/n02114712/n02114712_22151.JPEG': 439,
#  'train/n02114712/n02114712_17646.JPEG': 439,
#  'train/n02114712/n02114712_20669.JPEG': 439,
#  'train/n02114712/n02114712_15886.JPEG': 439,
#  'train/n02114712/n02114712_399.JPEG': 439,
#  'train/n02114712/n02114712_5322.JPEG': 439,
#  'train/n02114712/n02114712_18663.JPEG': 439,
#  'train/n02114712/n02114712_5175.JPEG': 439,
#  'train/n02114712/n02114712_672.JPEG': 439,
#  'train/n02114712/n02114712_11702.JPEG': 439,
#  'train/n02114712/n02114712_2698.JPEG': 439,
#  'train/n02114712/n02114712_1587.JPEG': 439,
#  'train/n02114712/n02114712_15565.JPEG': 439,
#  'train/n02114712/n02114712_18969.JPEG': 439,
#  'train/n02114712/n02114712_14353.JPEG': 439,
#  'train/n02114712/n02114712_20057.JPEG': 439,
#  'train/n02114712/n02114712_22911.JPEG': 439,
#  'train/n02114712/n02114712_3000.JPEG': 439,
#  'train/n02114712/n02114712_17584.JPEG': 439,
#  'train/n02114712/n02114712_17341.JPEG': 439,
#  'train/n02114712/n02114712_11472.JPEG': 439,
#  'train/n02114712/n02114712_3718.JPEG': 439,
#  'train/n02114712/n02114712_10153.JPEG': 439,
#  'train/n02114712/n02114712_13489.JPEG': 439,
#  'train/n02114712/n02114712_14903.JPEG': 439,
#  'train/n02114712/n02114712_9014.JPEG': 439,
#  'train/n02114712/n02114712_23323.JPEG': 439,
#  'train/n02114712/n02114712_19386.JPEG': 439,
#  'train/n02114712/n02114712_22714.JPEG': 439,
#  'train/n02114712/n02114712_18096.JPEG': 439,
#  'train/n02114712/n02114712_8817.JPEG': 439,
#  'train/n02114712/n02114712_19056.JPEG': 439,
#  'train/n02114712/n02114712_13860.JPEG': 439,
#  'train/n02114712/n02114712_5487.JPEG': 439,
#  'train/n02114712/n02114712_17403.JPEG': 439,
#  'train/n02114712/n02114712_1759.JPEG': 439,
#  'train/n02114712/n02114712_3868.JPEG': 439,
#  'train/n02114712/n02114712_5490.JPEG': 439,
#  'train/n02114712/n02114712_20453.JPEG': 439,
#  'train/n02114712/n02114712_17524.JPEG': 439,
#  'train/n02114712/n02114712_2111.JPEG': 439,
#  'train/n02114712/n02114712_10636.JPEG': 439,
#  'train/n02114712/n02114712_1014.JPEG': 439,
#  'train/n02114712/n02114712_17964.JPEG': 439,
#  'train/n02114712/n02114712_15987.JPEG': 439,
#  'train/n02114712/n02114712_16668.JPEG': 439,
#  'train/n02114712/n02114712_2543.JPEG': 439,
#  'train/n02114712/n02114712_18371.JPEG': 439,
#  'train/n02114712/n02114712_2285.JPEG': 439,
#  'train/n02114712/n02114712_9956.JPEG': 439,
#  'train/n02114712/n02114712_3978.JPEG': 439,
#  'train/n02114712/n02114712_24115.JPEG': 439,
#  'train/n02114712/n02114712_7639.JPEG': 439,
#  'train/n02114712/n02114712_4532.JPEG': 439,
#  'train/n02114712/n02114712_1347.JPEG': 439,
#  'train/n02114712/n02114712_23826.JPEG': 439,
#  'train/n02114712/n02114712_16228.JPEG': 439,
#  'train/n02114712/n02114712_23122.JPEG': 439,
#  'train/n02114712/n02114712_2184.JPEG': 439,
#  'train/n02114712/n02114712_243.JPEG': 439,
#  'train/n02114712/n02114712_3479.JPEG': 439,
#  'train/n02114712/n02114712_5358.JPEG': 439,
#  'train/n02114712/n02114712_17554.JPEG': 439,
#  'train/n02114712/n02114712_23067.JPEG': 439,
#  'train/n02114712/n02114712_16448.JPEG': 439,
#  'train/n02114712/n02114712_5242.JPEG': 439,
#  'train/n02114712/n02114712_11550.JPEG': 439,
#  'train/n02114712/n02114712_16659.JPEG': 439,
#  'train/n02114712/n02114712_7615.JPEG': 439,
#  'train/n02114712/n02114712_5734.JPEG': 439,
#  'train/n02114712/n02114712_15649.JPEG': 439,
#  'train/n02114712/n02114712_3605.JPEG': 439,
#  'train/n02114712/n02114712_8602.JPEG': 439,
#  'train/n02114712/n02114712_22498.JPEG': 439,
#  'train/n02114712/n02114712_22342.JPEG': 439,
#  'train/n02114712/n02114712_1093.JPEG': 439,
#  'train/n02114712/n02114712_19603.JPEG': 439,
#  'train/n02114712/n02114712_3951.JPEG': 439,
#  'train/n02114712/n02114712_17178.JPEG': 439,
#  'train/n02114712/n02114712_3954.JPEG': 439,
#  'train/n02114712/n02114712_18550.JPEG': 439,
#  'train/n02114712/n02114712_23809.JPEG': 439,
#  'train/n02114712/n02114712_23893.JPEG': 439,
#  'train/n02114712/n02114712_15651.JPEG': 439,
#  'train/n02114712/n02114712_1135.JPEG': 439,
#  'train/n02114712/n02114712_19717.JPEG': 439,
#  'train/n02114712/n02114712_16369.JPEG': 439,
#  'train/n02114712/n02114712_7088.JPEG': 439,
#  'train/n02114712/n02114712_15777.JPEG': 439,
#  'train/n02114712/n02114712_13796.JPEG': 439,
#  'train/n02114712/n02114712_9759.JPEG': 439,
#  'train/n02114712/n02114712_21589.JPEG': 439,
#  'train/n02114712/n02114712_4294.JPEG': 439,
#  'train/n02114712/n02114712_20518.JPEG': 439,
#  'train/n02114712/n02114712_18558.JPEG': 439,
#  'train/n02114712/n02114712_2814.JPEG': 439,
#  'train/n02114712/n02114712_19783.JPEG': 439,
#  'train/n02114712/n02114712_18447.JPEG': 439,
#  'train/n02114712/n02114712_17343.JPEG': 439,
#  'train/n02114712/n02114712_10260.JPEG': 439,
#  'train/n02114712/n02114712_2783.JPEG': 439,
#  'train/n02114712/n02114712_230.JPEG': 439,
#  'train/n02114712/n02114712_21875.JPEG': 439,
#  'train/n02114712/n02114712_17783.JPEG': 439,
#  'train/n02114712/n02114712_4383.JPEG': 439,
#  'train/n02114712/n02114712_18329.JPEG': 439,
#  'train/n02114712/n02114712_13610.JPEG': 439,
#  'train/n02114712/n02114712_13329.JPEG': 439,
#  'train/n02114712/n02114712_15511.JPEG': 439,
#  'train/n02114712/n02114712_3724.JPEG': 439,
#  'train/n02114712/n02114712_21802.JPEG': 439,
#  'train/n02114712/n02114712_23384.JPEG': 439,
#  'train/n02114712/n02114712_18126.JPEG': 439,
#  'train/n02114712/n02114712_8759.JPEG': 439,
#  'train/n02114712/n02114712_6790.JPEG': 439,
#  'train/n02114712/n02114712_9554.JPEG': 439,
#  'train/n02114712/n02114712_19825.JPEG': 439,
#  'train/n02114712/n02114712_10343.JPEG': 439,
#  'train/n02114712/n02114712_3037.JPEG': 439,
#  'train/n02114712/n02114712_1679.JPEG': 439,
#  'train/n02114712/n02114712_20619.JPEG': 439,
#  'train/n02114712/n02114712_15360.JPEG': 439,
#  'train/n02114712/n02114712_19257.JPEG': 439,
#  'train/n02114712/n02114712_1214.JPEG': 439,
#  'train/n02114712/n02114712_3971.JPEG': 439,
#  'train/n02114712/n02114712_14806.JPEG': 439,
#  'train/n02114712/n02114712_5298.JPEG': 439,
#  'train/n02114712/n02114712_22530.JPEG': 439,
#  'train/n02114712/n02114712_22835.JPEG': 439,
#  'train/n02114712/n02114712_3620.JPEG': 439,
#  'train/n02114712/n02114712_16554.JPEG': 439,
#  'train/n02114712/n02114712_6659.JPEG': 439,
#  'train/n02114712/n02114712_13120.JPEG': 439,
#  'train/n02114712/n02114712_3309.JPEG': 439,
#  'train/n02114712/n02114712_350.JPEG': 439,
#  'train/n02114712/n02114712_1745.JPEG': 439,
#  'train/n02114712/n02114712_4422.JPEG': 439,
#  'train/n02114712/n02114712_22033.JPEG': 439,
#  'train/n02114712/n02114712_23249.JPEG': 439,
#  'train/n02114712/n02114712_17491.JPEG': 439,
#  'train/n02114712/n02114712_14726.JPEG': 439,
#  'train/n02114712/n02114712_2060.JPEG': 439,
#  'train/n02114712/n02114712_15347.JPEG': 439,
#  'train/n02114712/n02114712_21854.JPEG': 439,
#  'train/n02114712/n02114712_19278.JPEG': 439,
#  'train/n02114712/n02114712_17608.JPEG': 439,
#  'train/n02114712/n02114712_15623.JPEG': 439,
#  'train/n02114712/n02114712_19883.JPEG': 439,
#  'train/n02114712/n02114712_16289.JPEG': 439,
#  'train/n02114712/n02114712_17661.JPEG': 439,
#  'train/n02114712/n02114712_16595.JPEG': 439,
#  'train/n02114712/n02114712_3440.JPEG': 439,
#  'train/n02114712/n02114712_1537.JPEG': 439,
#  'train/n02114712/n02114712_7076.JPEG': 439,
#  'train/n02114712/n02114712_2393.JPEG': 439,
#  'train/n02114712/n02114712_21701.JPEG': 439,
#  'train/n02114712/n02114712_136.JPEG': 439,
#  'train/n02114712/n02114712_18525.JPEG': 439,
#  'train/n02114712/n02114712_4216.JPEG': 439,
#  'train/n02114712/n02114712_23227.JPEG': 439,
#  'train/n02114712/n02114712_17845.JPEG': 439,
#  'train/n02114712/n02114712_11171.JPEG': 439,
#  'train/n02114712/n02114712_6807.JPEG': 439,
#  'train/n02114712/n02114712_5401.JPEG': 439,
#  'train/n02114712/n02114712_7831.JPEG': 439,
#  'train/n02114712/n02114712_17029.JPEG': 439,
#  'train/n02114712/n02114712_7874.JPEG': 439,
#  'train/n02114712/n02114712_7794.JPEG': 439,
#  'train/n02114712/n02114712_14298.JPEG': 439,
#  'train/n02114712/n02114712_23853.JPEG': 439,
#  'train/n02114712/n02114712_16564.JPEG': 439,
#  'train/n02114712/n02114712_4445.JPEG': 439,
#  'train/n02114712/n02114712_17517.JPEG': 439,
#  'train/n02114712/n02114712_6521.JPEG': 439,
#  'train/n02114712/n02114712_17786.JPEG': 439,
#  'train/n02114712/n02114712_20087.JPEG': 439,
#  'train/n02114712/n02114712_3645.JPEG': 439,
#  'train/n02114712/n02114712_13766.JPEG': 439,
#  'train/n02114712/n02114712_16534.JPEG': 439,
#  'train/n02114712/n02114712_20889.JPEG': 439,
#  'train/n02114712/n02114712_18675.JPEG': 439,
#  'train/n02114712/n02114712_1206.JPEG': 439,
#  'train/n02114712/n02114712_18760.JPEG': 439,
#  'train/n02114712/n02114712_20055.JPEG': 439,
#  'train/n02114712/n02114712_17118.JPEG': 439,
#  'train/n02114712/n02114712_15076.JPEG': 439,
#  'train/n02114712/n02114712_5609.JPEG': 439,
#  'train/n02114712/n02114712_6363.JPEG': 439,
#  'train/n02114712/n02114712_6016.JPEG': 439,
#  'train/n02114712/n02114712_18098.JPEG': 439,
#  'train/n02114712/n02114712_8749.JPEG': 439,
#  'train/n02114712/n02114712_15850.JPEG': 439,
#  'train/n02114712/n02114712_13215.JPEG': 439,
#  'train/n02114712/n02114712_20460.JPEG': 439,
#  'train/n02114712/n02114712_1609.JPEG': 439,
#  'train/n02114712/n02114712_17658.JPEG': 439,
#  'train/n02114712/n02114712_8927.JPEG': 439,
#  'train/n02114712/n02114712_6222.JPEG': 439,
#  'train/n02114712/n02114712_6751.JPEG': 439,
#  'train/n02114712/n02114712_21901.JPEG': 439,
#  'train/n02114712/n02114712_3065.JPEG': 439,
#  'train/n02114712/n02114712_10216.JPEG': 439,
#  'train/n02114712/n02114712_15583.JPEG': 439,
#  'train/n02114712/n02114712_5097.JPEG': 439,
#  'train/n02114712/n02114712_16500.JPEG': 439,
#  'train/n02114712/n02114712_2123.JPEG': 439,
#  'train/n02114712/n02114712_22372.JPEG': 439,
#  'train/n02114712/n02114712_2807.JPEG': 439,
#  'train/n02114712/n02114712_17461.JPEG': 439,
#  'train/n02114712/n02114712_23391.JPEG': 439,
#  'train/n02114712/n02114712_22777.JPEG': 439,
#  'train/n02114712/n02114712_6399.JPEG': 439,
#  'train/n02114712/n02114712_21545.JPEG': 439,
#  'train/n02114712/n02114712_17436.JPEG': 439,
#  'train/n02114712/n02114712_9991.JPEG': 439,
#  'train/n02114712/n02114712_17000.JPEG': 439,
#  'train/n02114712/n02114712_20822.JPEG': 439,
#  'train/n02114712/n02114712_19658.JPEG': 439,
#  'train/n02114712/n02114712_15038.JPEG': 439,
#  'train/n02114712/n02114712_14824.JPEG': 439,
#  'train/n02114712/n02114712_5463.JPEG': 439,
#  'train/n02114712/n02114712_20091.JPEG': 439,
#  'train/n02114712/n02114712_19175.JPEG': 439,
#  'train/n02114712/n02114712_18522.JPEG': 439,
#  'train/n02114712/n02114712_5324.JPEG': 439,
#  'train/n02114712/n02114712_279.JPEG': 439,
#  'train/n02114712/n02114712_20161.JPEG': 439,
#  'train/n02114712/n02114712_16706.JPEG': 439,
#  'train/n02114712/n02114712_12602.JPEG': 439,
#  'train/n02114712/n02114712_12015.JPEG': 439,
#  'train/n02114712/n02114712_23630.JPEG': 439,
#  'train/n02114712/n02114712_10317.JPEG': 439,
#  'train/n02114712/n02114712_16424.JPEG': 439,
#  'train/n02114712/n02114712_13775.JPEG': 439,
#  'train/n02114712/n02114712_22916.JPEG': 439,
#  'train/n02114712/n02114712_1467.JPEG': 439,
#  'train/n02114712/n02114712_23154.JPEG': 439,
#  'train/n02114712/n02114712_9465.JPEG': 439,
#  'train/n02114712/n02114712_16694.JPEG': 439,
#  'train/n02114712/n02114712_5025.JPEG': 439,
#  'train/n02114712/n02114712_19468.JPEG': 439,
#  'train/n02114712/n02114712_1420.JPEG': 439,
#  'train/n02114712/n02114712_15479.JPEG': 439,
#  'train/n02114712/n02114712_6548.JPEG': 439,
#  'train/n02114712/n02114712_21870.JPEG': 439,
#  'train/n02114712/n02114712_12350.JPEG': 439,
#  'train/n02114712/n02114712_13067.JPEG': 439,
#  'train/n02114712/n02114712_6839.JPEG': 439,
#  'train/n02114712/n02114712_5881.JPEG': 439,
#  'train/n02114712/n02114712_22903.JPEG': 439,
#  'train/n02114712/n02114712_2051.JPEG': 439,
#  'train/n02114712/n02114712_8613.JPEG': 439,
#  'train/n02114712/n02114712_23511.JPEG': 439,
#  'train/n02114712/n02114712_23291.JPEG': 439,
#  'train/n02114712/n02114712_18965.JPEG': 439,
#  'train/n02114712/n02114712_16985.JPEG': 439,
#  'train/n02114712/n02114712_3181.JPEG': 439,
#  'train/n02114712/n02114712_15786.JPEG': 439,
#  'train/n02114712/n02114712_17837.JPEG': 439,
#  'train/n02114712/n02114712_23946.JPEG': 439,
#  'train/n02114712/n02114712_16152.JPEG': 439,
#  'train/n02114712/n02114712_5951.JPEG': 439,
#  'train/n02114712/n02114712_18095.JPEG': 439,
#  'train/n02114712/n02114712_8298.JPEG': 439,
#  'train/n02114712/n02114712_690.JPEG': 439,
#  'train/n02114712/n02114712_35.JPEG': 439,
#  'train/n02114712/n02114712_22850.JPEG': 439,
#  'train/n02114712/n02114712_7989.JPEG': 439,
#  'train/n02114712/n02114712_338.JPEG': 439,
#  'train/n02114712/n02114712_20626.JPEG': 439,
#  'train/n02114712/n02114712_2769.JPEG': 439,
#  'train/n02114712/n02114712_23371.JPEG': 439,
#  'train/n02114712/n02114712_13910.JPEG': 439,
#  'train/n02114712/n02114712_22889.JPEG': 439,
#  'train/n02114712/n02114712_5756.JPEG': 439,
#  'train/n02114712/n02114712_5131.JPEG': 439,
#  'train/n02114712/n02114712_20246.JPEG': 439,
#  'train/n02114712/n02114712_19680.JPEG': 439,
#  'train/n02114712/n02114712_16071.JPEG': 439,
#  'train/n02114712/n02114712_15806.JPEG': 439,
#  'train/n02114712/n02114712_14406.JPEG': 439,
#  'train/n02114712/n02114712_6300.JPEG': 439,
#  'train/n02114712/n02114712_8608.JPEG': 439,
#  'train/n02114712/n02114712_17556.JPEG': 439,
#  'train/n02114712/n02114712_11401.JPEG': 439,
#  'train/n02114712/n02114712_20369.JPEG': 439,
#  'train/n02114712/n02114712_13042.JPEG': 439,
#  'train/n02114712/n02114712_22453.JPEG': 439,
#  'train/n02114712/n02114712_17609.JPEG': 439,
#  'train/n02114712/n02114712_9281.JPEG': 439,
#  'train/n02114712/n02114712_13648.JPEG': 439,
#  'train/n02114712/n02114712_20197.JPEG': 439,
#  'train/n02114712/n02114712_2560.JPEG': 439,
#  'train/n02114712/n02114712_14503.JPEG': 439,
#  'train/n02114712/n02114712_58.JPEG': 439,
#  'train/n02114712/n02114712_15846.JPEG': 439,
#  'train/n02114712/n02114712_13142.JPEG': 439,
#  'train/n02114712/n02114712_20472.JPEG': 439,
#  'train/n02114712/n02114712_17810.JPEG': 439,
#  'train/n02114712/n02114712_15814.JPEG': 439,
#  'train/n02114712/n02114712_2509.JPEG': 439,
#  'train/n02114712/n02114712_23220.JPEG': 439,
#  'train/n02114712/n02114712_2830.JPEG': 439,
#  'train/n02114712/n02114712_8488.JPEG': 439,
#  'train/n02114712/n02114712_7067.JPEG': 439,
#  'train/n02114712/n02114712_15134.JPEG': 439,
#  'train/n02114712/n02114712_14598.JPEG': 439,
#  'train/n02114712/n02114712_5833.JPEG': 439,
#  'train/n02114712/n02114712_19037.JPEG': 439,
#  'train/n02114712/n02114712_13613.JPEG': 439,
#  'train/n02114712/n02114712_15137.JPEG': 439,
#  'train/n02114712/n02114712_1417.JPEG': 439,
#  'train/n02114712/n02114712_16824.JPEG': 439,
#  'train/n02114712/n02114712_15493.JPEG': 439,
#  'train/n02114712/n02114712_1141.JPEG': 439,
#  'train/n02114712/n02114712_942.JPEG': 439,
#  'train/n02114712/n02114712_11287.JPEG': 439,
#  'train/n02114712/n02114712_13840.JPEG': 439,
#  'train/n02114712/n02114712_21632.JPEG': 439,
#  'train/n02114712/n02114712_5422.JPEG': 439,
#  'train/n02114712/n02114712_6732.JPEG': 439,
#  'train/n02114712/n02114712_5592.JPEG': 439,
#  'train/n02114712/n02114712_16533.JPEG': 439,
#  'train/n02114712/n02114712_3009.JPEG': 439,
#  'train/n02114712/n02114712_20099.JPEG': 439,
#  'train/n02114712/n02114712_17203.JPEG': 439,
#  'train/n02114712/n02114712_5439.JPEG': 439,
#  'train/n02114712/n02114712_20890.JPEG': 439,
#  'train/n02114712/n02114712_19661.JPEG': 439,
#  'train/n02114712/n02114712_5183.JPEG': 439,
#  'train/n02114712/n02114712_20739.JPEG': 439,
#  'train/n02114712/n02114712_3992.JPEG': 439,
#  'train/n02114712/n02114712_16099.JPEG': 439,
#  'train/n02114712/n02114712_18713.JPEG': 439,
#  'train/n02114712/n02114712_17999.JPEG': 439,
#  'train/n02114712/n02114712_1052.JPEG': 439,
#  'train/n02114712/n02114712_6497.JPEG': 439,
#  'train/n02114712/n02114712_21694.JPEG': 439,
#  'train/n02114712/n02114712_14916.JPEG': 439,
#  'train/n02114712/n02114712_13218.JPEG': 439,
#  'train/n02114712/n02114712_1145.JPEG': 439,
#  'train/n02114712/n02114712_16845.JPEG': 439,
#  'train/n02114712/n02114712_24253.JPEG': 439,
#  'train/n02114712/n02114712_23034.JPEG': 439,
#  'train/n02114712/n02114712_15325.JPEG': 439,
#  'train/n02114712/n02114712_18922.JPEG': 439,
#  'train/n02114712/n02114712_8319.JPEG': 439,
#  'train/n02114712/n02114712_18805.JPEG': 439,
#  'train/n02114712/n02114712_23859.JPEG': 439,
#  'train/n02114712/n02114712_2867.JPEG': 439,
#  'train/n02114712/n02114712_7901.JPEG': 439,
#  'train/n02114712/n02114712_9798.JPEG': 439,
#  'train/n02114712/n02114712_20088.JPEG': 439,
#  'train/n02114712/n02114712_24014.JPEG': 439,
#  'train/n02114712/n02114712_1852.JPEG': 439,
#  'train/n02114712/n02114712_1148.JPEG': 439,
#  'train/n02114712/n02114712_13588.JPEG': 439,
#  'train/n02114712/n02114712_20033.JPEG': 439,
#  'train/n02114712/n02114712_10504.JPEG': 439,
#  'train/n02114712/n02114712_23222.JPEG': 439,
#  'train/n02114712/n02114712_12697.JPEG': 439,
#  'train/n02114712/n02114712_2975.JPEG': 439,
#  'train/n02114712/n02114712_15883.JPEG': 439,
#  'train/n02114712/n02114712_9418.JPEG': 439,
#  'train/n02114712/n02114712_17482.JPEG': 439,
#  'train/n02114712/n02114712_5733.JPEG': 439,
#  'train/n02114712/n02114712_984.JPEG': 439,
#  'train/n02114712/n02114712_17905.JPEG': 439,
#  'train/n02114712/n02114712_2927.JPEG': 439,
#  'train/n02114712/n02114712_22684.JPEG': 439,
#  'train/n02114712/n02114712_8051.JPEG': 439,
#  'train/n02114712/n02114712_23517.JPEG': 439,
#  'train/n02114712/n02114712_1653.JPEG': 439,
#  'train/n02114712/n02114712_717.JPEG': 439,
#  'train/n02114712/n02114712_19179.JPEG': 439,
#  'train/n02114712/n02114712_12377.JPEG': 439,
#  'train/n02114712/n02114712_19752.JPEG': 439,
#  'train/n02114712/n02114712_21583.JPEG': 439,
#  'train/n02114712/n02114712_17823.JPEG': 439,
#  'train/n02114712/n02114712_17500.JPEG': 439,
#  'train/n02114712/n02114712_1454.JPEG': 439,
#  'train/n02114712/n02114712_7931.JPEG': 439,
#  'train/n02114712/n02114712_5369.JPEG': 439,
#  'train/n02114712/n02114712_19766.JPEG': 439,
#  'train/n02114712/n02114712_16372.JPEG': 439,
#  'train/n02114712/n02114712_10338.JPEG': 439,
#  'train/n02114712/n02114712_14377.JPEG': 439,
#  'train/n02114712/n02114712_6358.JPEG': 439,
#  'train/n02114712/n02114712_1249.JPEG': 439,
#  'train/n02114712/n02114712_1599.JPEG': 439,
#  'train/n02114712/n02114712_8734.JPEG': 439,
#  'train/n02114712/n02114712_17364.JPEG': 439,
#  'train/n02114712/n02114712_16615.JPEG': 439,
#  'train/n02114712/n02114712_17701.JPEG': 439,
#  'train/n02114712/n02114712_5728.JPEG': 439,
#  'train/n02114712/n02114712_8240.JPEG': 439,
#  'train/n02114712/n02114712_22943.JPEG': 439,
#  'train/n02114712/n02114712_1804.JPEG': 439,
#  'train/n02114712/n02114712_3818.JPEG': 439,
#  'train/n02114712/n02114712_2870.JPEG': 439,
#  'train/n02114712/n02114712_19397.JPEG': 439,
#  'train/n02114712/n02114712_17954.JPEG': 439,
#  'train/n02114712/n02114712_18972.JPEG': 439,
#  'train/n02114712/n02114712_1886.JPEG': 439,
#  'train/n02114712/n02114712_16524.JPEG': 439,
#  'train/n02114712/n02114712_18982.JPEG': 439,
#  'train/n02114712/n02114712_6948.JPEG': 439,
#  'train/n02114712/n02114712_20707.JPEG': 439,
#  'train/n02114712/n02114712_23264.JPEG': 439,
#  'train/n02114712/n02114712_20543.JPEG': 439,
#  'train/n02114712/n02114712_9933.JPEG': 439,
#  'train/n02114712/n02114712_16858.JPEG': 439,
#  'train/n02114712/n02114712_18353.JPEG': 439,
#  'train/n02114712/n02114712_23499.JPEG': 439,
#  'train/n02114712/n02114712_12168.JPEG': 439,
#  'train/n02114712/n02114712_20250.JPEG': 439,
#  'train/n02114712/n02114712_23176.JPEG': 439,
#  'train/n02114712/n02114712_21690.JPEG': 439,
#  'train/n02114712/n02114712_22722.JPEG': 439,
#  'train/n02114712/n02114712_18455.JPEG': 439,
#  'train/n02114712/n02114712_18568.JPEG': 439,
#  'train/n02114712/n02114712_10138.JPEG': 439,
#  'train/n02114712/n02114712_22118.JPEG': 439,
#  'train/n02114712/n02114712_15531.JPEG': 439,
#  'train/n02114712/n02114712_9522.JPEG': 439,
#  'train/n02114712/n02114712_15745.JPEG': 439,
#  'train/n02114712/n02114712_7441.JPEG': 439,
#  'train/n02114712/n02114712_17105.JPEG': 439,
#  'train/n02114712/n02114712_17951.JPEG': 439,
#  'train/n02114712/n02114712_1426.JPEG': 439,
#  'train/n02114712/n02114712_6959.JPEG': 439,
#  'train/n02114712/n02114712_19945.JPEG': 439,
#  'train/n02114712/n02114712_7396.JPEG': 439,
#  'train/n02114712/n02114712_1595.JPEG': 439,
#  'train/n02114712/n02114712_725.JPEG': 439,
#  'train/n02114712/n02114712_14770.JPEG': 439,
#  'train/n02114712/n02114712_23911.JPEG': 439,
#  'train/n02114712/n02114712_18072.JPEG': 439,
#  'train/n02114712/n02114712_24113.JPEG': 439,
#  'train/n02114712/n02114712_16269.JPEG': 439,
#  'train/n02114712/n02114712_3467.JPEG': 439,
#  'train/n02114712/n02114712_3431.JPEG': 439,
#  'train/n02114712/n02114712_19929.JPEG': 439,
#  'train/n02114712/n02114712_18749.JPEG': 439,
#  'train/n02114712/n02114712_20867.JPEG': 439,
#  'train/n02114712/n02114712_2551.JPEG': 439,
#  'train/n02114712/n02114712_18144.JPEG': 439,
#  'train/n02114712/n02114712_8333.JPEG': 439,
#  'train/n02114712/n02114712_5296.JPEG': 439,
#  'train/n02114712/n02114712_18415.JPEG': 439,
#  'train/n02114712/n02114712_16351.JPEG': 439,
#  'train/n02114712/n02114712_5325.JPEG': 439,
#  'train/n02114712/n02114712_15532.JPEG': 439,
#  'train/n02114712/n02114712_4963.JPEG': 439,
#  'train/n02114712/n02114712_11577.JPEG': 439,
#  'train/n02114712/n02114712_21290.JPEG': 439,
#  'train/n02114712/n02114712_21568.JPEG': 439,
#  'train/n02114712/n02114712_16480.JPEG': 439,
#  'train/n02114712/n02114712_5622.JPEG': 439,
#  'train/n02114712/n02114712_21075.JPEG': 439,
#  'train/n02114712/n02114712_14883.JPEG': 439,
#  'train/n02114712/n02114712_2420.JPEG': 439,
#  'train/n02114712/n02114712_4969.JPEG': 439,
#  'train/n02114712/n02114712_6828.JPEG': 439,
#  'train/n02114712/n02114712_2593.JPEG': 439,
#  'train/n02114712/n02114712_23599.JPEG': 439,
#  'train/n02114712/n02114712_4680.JPEG': 439,
#  'train/n02114712/n02114712_11214.JPEG': 439,
#  'train/n02114712/n02114712_6638.JPEG': 439,
#  'train/n02114712/n02114712_22232.JPEG': 439,
#  'train/n02114712/n02114712_23240.JPEG': 439,
#  'train/n02114712/n02114712_7828.JPEG': 439,
#  'train/n02114712/n02114712_11324.JPEG': 439,
#  'train/n02114712/n02114712_2640.JPEG': 439,
#  'train/n02114712/n02114712_17929.JPEG': 439,
#  'train/n02114712/n02114712_18578.JPEG': 439,
#  'train/n02114712/n02114712_22915.JPEG': 439,
#  'train/n02114712/n02114712_20550.JPEG': 439,
#  'train/n02114712/n02114712_1958.JPEG': 439,
#  'train/n02114712/n02114712_2438.JPEG': 439,
#  'train/n02114712/n02114712_12435.JPEG': 439,
#  'train/n02114712/n02114712_6109.JPEG': 439,
#  'train/n02114712/n02114712_5491.JPEG': 439,
#  'train/n02114712/n02114712_17843.JPEG': 439,
#  'train/n02114712/n02114712_20620.JPEG': 439,
#  'train/n02114712/n02114712_17758.JPEG': 439,
#  'train/n02114712/n02114712_23959.JPEG': 439,
#  'train/n02114712/n02114712_9626.JPEG': 439,
#  'train/n02114712/n02114712_18027.JPEG': 439,
#  'train/n02114712/n02114712_16346.JPEG': 439,
#  'train/n02114712/n02114712_988.JPEG': 439,
#  'train/n02114712/n02114712_22469.JPEG': 439,
#  'train/n02114712/n02114712_15280.JPEG': 439,
#  'train/n02114712/n02114712_299.JPEG': 439,
#  'train/n02114712/n02114712_14651.JPEG': 439,
#  'train/n02114712/n02114712_6179.JPEG': 439,
#  'train/n02114712/n02114712_14848.JPEG': 439,
#  'train/n02114712/n02114712_17172.JPEG': 439,
#  'train/n02114712/n02114712_23195.JPEG': 439,
#  'train/n02114712/n02114712_12561.JPEG': 439,
#  'train/n02114712/n02114712_17335.JPEG': 439,
#  'train/n02114712/n02114712_5963.JPEG': 439,
#  'train/n02114712/n02114712_20406.JPEG': 439,
#  'train/n02114712/n02114712_4345.JPEG': 439,
#  'train/n02114712/n02114712_11706.JPEG': 439,
#  'train/n02114712/n02114712_6432.JPEG': 439,
#  'train/n02114712/n02114712_3156.JPEG': 439,
#  'train/n02114712/n02114712_14115.JPEG': 439,
#  'train/n02114712/n02114712_21437.JPEG': 439,
#  'train/n02114712/n02114712_4059.JPEG': 439,
#  'train/n02114712/n02114712_13085.JPEG': 439,
#  'train/n02114712/n02114712_21343.JPEG': 439,
#  'train/n02114712/n02114712_7030.JPEG': 439,
#  'train/n02114712/n02114712_6332.JPEG': 439,
#  'train/n02114712/n02114712_11418.JPEG': 439,
#  ...}

# %%
synsets[438]
# Out:
# array([(array([[439]], dtype=uint16), array(['n02114712'], dtype='<U9'), array(['red wolf, maned wolf, Canis rufus, Canis niger'], dtype='<U46'), array(['reddish-grey wolf of southwestern North America'], dtype='<U47'), array([[0]], dtype=uint8), array([], shape=(1, 0), dtype=uint8), array([[0]], dtype=uint8), array([[1156]], dtype=uint16))],
#       dtype=[('ILSVRC2010_ID', 'O'), ('WNID', 'O'), ('words', 'O'), ('gloss', 'O'), ('num_children', 'O'), ('children', 'O'), ('wordnet_height', 'O'), ('num_train_images', 'O')])

# %%
#extract the json file containing 1% label
with open('/storage/data/changyu/imagenet/train.json', 'r') as f:
    img_label_mapping = json.load(f)

# %%
#Only keep 1% of the labels in img_label_mapping 
new_img_label_mapping = {}
for key in img_label_mapping:
    if random.random() < 0.01:
        new_img_label_mapping[key] = img_label_mapping[key]

#save the new json file
with open('/storage/data/changyu/imagenet/train_1percent.json', 'w') as f:
    json.dump(new_img_label_mapping, f, indent=4)

# %%
#Only keep 3% of the labels in img_label_mapping 
new_img_label_mapping = {}
for key in img_label_mapping:
    if random.random() < 0.03:
        new_img_label_mapping[key] = img_label_mapping[key]

#save the new json file
with open('/storage/data/changyu/imagenet/train_3percent.json', 'w') as f:
    json.dump(new_img_label_mapping, f, indent=4)

# %%
#Only keep 5% of the labels in img_label_mapping 
new_img_label_mapping = {}
for key in img_label_mapping:
    if random.random() < 0.05:
        new_img_label_mapping[key] = img_label_mapping[key]

#save the new json file
with open('/storage/data/changyu/imagenet/train_5percent.json', 'w') as f:
    json.dump(new_img_label_mapping, f, indent=4)

# %%
#Only keep 10% of the labels in img_label_mapping 
new_img_label_mapping = {}
for key in img_label_mapping:
    if random.random() < 0.1:
        new_img_label_mapping[key] = img_label_mapping[key]

#save the new json file
with open('/storage/data/changyu/imagenet/train_10percent.json', 'w') as f:
    json.dump(new_img_label_mapping, f, indent=4)
